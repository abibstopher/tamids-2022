# %% [markdown]
# # Building Custom DataFrames for Various Uses
# **Filename:** building_custom_dfs.ipynb
# **Path:** TAMIDS/Code/Scholars@TAMU Data/building_custom_dfs.ipynb
# **Created Date:** 04 April 2022, 18:09
#
# In this document I build several custom DataFrames from the data I have collected.

# %%
from IPython.display import Markdown, display, HTML
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import json
import requests
from requests.exceptions import HTTPError
from tqdm import tqdm

pd.options.display.float_format = '{:,.3f}'.format
plt.style.use('seaborn-darkgrid')

# General Markdown Formatting Functions

def printmd(string, level=1):
    header_level = '#'*level + ' '
    display(Markdown(header_level + string))

# %% [markdown]
# ## Loading the Data
#
# Creates a dictionary of dictionaries of dataframes for all the pickeled data.
# Ex: `data['people_education']` contains the 'people_education' DataFrame loaded from `../../Data/Scholars@TAMU/people/people_education.pickle`.
# This makes calls to each DataFrame simpler than they were in the `pickling_raw_data.ipynb` and `completeness.ipynb` files.

# %%
base_path = "../../Data/Scholars@TAMU"

with open('dicts/data_filenames.json', 'r') as infile:
    data_filenames = json.load(infile)

data = {}
for foldername, filenames in data_filenames.items():
    for filename in filenames:
        data[filename] = pd.read_pickle(base_path + "/" + foldername + "/" + filename + ".pickle")

# %%
with open('../../Data/Scholars@TAMU/my_api_calls/general_data_dict.json', 'r') as infile:
    api = json.load(infile)

# %% [markdown]
# ## people
#
# Each row of this dataframe represents a unique person from Scholars@TAMU.

# %%
URL_PREFIX = 'https://scholars.library.tamu.edu/vivo/display/'
API_PREFIX = 'https://api.library.tamu.edu/scholars-discovery/individual/'

people = pd.DataFrame({
    'api_id': data['people_overview']['people_api'].apply(lambda x: x.replace('https://api.library.tamu.edu/scholars-discovery/individual/', '')),
    'uin': data['people_overview']['uin'],
    'lastname': data['people_overview']['lastname'],
    'middlename': data['people_overview']['middle'],
    'firstname': data['people_overview']['firstname'],
    'email': data['people_overview']['email'],
    'preferred_title': data['people_overview']['preferred_title'],
    'employment_type': data['people_overview']['status']

}).set_index('api_id')

# %%
def get_attribute_series(key: str, is_list=True) -> list | str:
    has_it_counter = {'Yes': 0, 'No': 0}
    def get_attribute(api_id: str) -> list:
        try:
            person = api[api_id]
        except KeyError:
            return []

        try:
            if is_list:
                attribute_list = [attribute for attribute in person[key]]
            else:
                attribute_list = person[key]
            has_it_counter['Yes'] += 1
        except KeyError:
            if is_list:
                attribute_list = []
            else:
                attribute_list = ''
            has_it_counter['No'] += 1

        return attribute_list

    s = people.index.map(get_attribute)
    print(f"{key}: {has_it_counter}")
    return s

# %%
people['research_areas'] = get_attribute_series(key='researchAreas')
people['keywords'] = get_attribute_series(key='keywords')
people['colleges'] = get_attribute_series(key='schools')
people['organizations'] = get_attribute_series(key='organizations')
people['education'] = get_attribute_series(key='educationAndTraining')
people['teaching'] = get_attribute_series(key='teachingActivities')
people['publications'] = get_attribute_series(key='publications')
people['hr_title'] = get_attribute_series(key='hrJobTitle', is_list=False)
people['all_positions'] = get_attribute_series(key='positions')
people['overview'] = get_attribute_series(key='overview', is_list=False)
# Out:
# researchAreas: {'Yes': 643, 'No': 4189}
# keywords: {'Yes': 3099, 'No': 1733}
# schools: {'Yes': 4583, 'No': 249}
# organizations: {'Yes': 4775, 'No': 57}
# educationAndTraining: {'Yes': 3054, 'No': 1778}
# teachingActivities: {'Yes': 3874, 'No': 958}
# publications: {'Yes': 3304, 'No': 1528}
# hrJobTitle: {'Yes': 4822, 'No': 10}
# positions: {'Yes': 4775, 'No': 57}
# overview: {'Yes': 1788, 'No': 3044}

# %%
people
# Out:
#                  uin     lastname middlename    firstname  \
# api_id
# n28cb7333  706006006       Carter          H        Misti
# n014c3d0f  502001050        Allen          C        Gregg
# n7a168a93  902000258       Dubois          W       Dustin
# nbccd1f64  202004708       Mccord          C         Gary
# n18de9127  919002271       Bondos          E        Sarah
# ...              ...          ...        ...          ...
# nc1e62471  701002712        Ferro          J       Pamela
# n14b2580b  730003535  Chakraborty        NaN      Joydeep
# n4f37dfa5  324003135         Dvir        NaN        Rotem
# n0e788fcb  231005803        Agadi        NaN       Satish
# nca549702  504006103        Smith      SHANE  Christopher
#
#                             email                      preferred_title  \
# api_id
# n28cb7333     hillcarter@tamu.edu                  Assistant Professor
# n014c3d0f    gregg.allen@tamu.edu                  Associate Professor
# n7a168a93         dubois@tamu.edu                  Assistant Professor
# nbccd1f64       g-mccord@tamu.edu                            Professor
# n18de9127         bondos@tamu.edu                  Associate Professor
# ...                           ...                                  ...
# nc1e62471        p-ferro@tamu.edu  Section Head, Molecular Diagnostics
# n14b2580b  joydeep.c2019@tamu.edu              Postdoctoral Researcher
# n4f37dfa5          rdvir@tamu.edu         Assistant Research Scientist
# n0e788fcb          agadi@tamu.edu         Clinical Assistant Professor
# nca549702  chrissmith442@tamu.edu                             Lecturer
#
#           employment_type                                     research_areas  \
# api_id
# n28cb7333         Faculty                                                 []
# n014c3d0f         Faculty                                                 []
# n7a168a93         Faculty                                                 []
# nbccd1f64           Staff                                                 []
# n18de9127         Faculty                                                 []
# ...                   ...                                                ...
# nc1e62471           Staff                                                 []
# n14b2580b           Staff  [{'id': 'nfst01036069', 'label': 'Nerves, Peri...
# n4f37dfa5           Staff  [{'id': 'nfst01110895', 'label': 'Security, In...
# n0e788fcb           Staff                                                 []
# nca549702           Staff                                                 []
#
#                                                     keywords  \
# api_id
# n28cb7333                                                 []
# n014c3d0f  [Photoreceptor Cells, Vertebrate, Glycine, Gam...
# n7a168a93  [Sipsc, Ethanol, Excitatory Postsynaptic Poten...
# nbccd1f64  [Tendinopathy, Bursitis, Hydroxyapatites, Calc...
# n18de9127  [Recombinant Fusion Proteins, Gene Expression,...
# ...                                                      ...
# nc1e62471  [Viral Envelope Proteins, Sensitivity And Spec...
# n14b2580b  [Saturation Mutagenesis, 2-oxo Acid Dehydrogen...
# n4f37dfa5      [8.3 Policy, Ethics, And Research Governance]
# n0e788fcb                                                 []
# nca549702                                                 []
#
#                                                     colleges  \
# api_id
# n28cb7333                              [College of Medicine]
# n014c3d0f                              [College of Medicine]
# n7a168a93                              [College of Medicine]
# nbccd1f64       [College of Medicine, Health Science Center]
# n18de9127                                                 []
# ...                                                      ...
# nc1e62471  [College of Veterinary Medicine and Biomedical...
# n14b2580b         [College of Agriculture and Life Sciences]
# n4f37dfa5     [Bush School of Government and Public Service]
# n0e788fcb                            [Health Science Center]
# nca549702                           [College of Engineering]
#
#                                                organizations  \
# api_id
# n28cb7333                           [Humanities in Medicine]
# n014c3d0f       [Neuroscience and Experimental Therapeutics]
# n7a168a93       [Neuroscience and Experimental Therapeutics]
# nbccd1f64  [Neuroscience and Experimental Therapeutics, C...
# n18de9127                                                 []
# ...                                                      ...
# nc1e62471  [Texas A&M Veterinary Medical Diagnostic Labor...
# n14b2580b                                        [Nutrition]
# n4f37dfa5  [Institute for Science, Technology, and Public...
# n0e788fcb                              [College of Medicine]
# nca549702  [Engineering Technology and Industrial Distrib...
#
#                                                    education  \
# api_id
# n28cb7333  [{'id': 'n28cb7333_c2acab6a-b3ca-11e9-adb7-001...
# n014c3d0f  [{'id': 'n014c3d0f_26a39892-b399-11e9-adb7-001...
# n7a168a93  [{'id': 'n7a168a93_c2acab6a-b3ca-11e9-adb7-001...
# nbccd1f64  [{'id': 'nbccd1f64_dc7dc0d0-b399-11e9-adb7-001...
# n18de9127  [{'id': 'n18de9127_580dfdad-b399-11e9-adb7-001...
# ...                                                      ...
# nc1e62471  [{'id': 'nc1e62471_dc7dc0d0-b399-11e9-adb7-001...
# n14b2580b  [{'id': 'n14b2580b_874490bb-b3ae-11e9-adb7-001...
# n4f37dfa5  [{'id': 'n4f37dfa5_3d0e6a4d-b399-11e9-adb7-001...
# n0e788fcb                                                 []
# nca549702  [{'id': 'nca549702_e51c3ee6-b399-11e9-adb7-001...
#
#                                                     teaching  \
# api_id
# n28cb7333  [{'id': 'n63e653c9', 'label': 'MEID610 Heal I'...
# n014c3d0f  [{'id': 'n9d4cc9ec', 'label': 'NEXT620 Gross A...
# n7a168a93  [{'id': 'n8f977c82', 'label': 'NEXT605 Moleclr...
# nbccd1f64  [{'id': 'n075561e4', 'label': 'MEID708 Integum...
# n18de9127  [{'id': 'nd8499416', 'label': 'MSCI691 Researc...
# ...                                                      ...
# nc1e62471                                                 []
# n14b2580b                                                 []
# n4f37dfa5  [{'id': 'na4f3301a', 'label': 'BUSH631 Quant M...
# n0e788fcb                                                 []
# nca549702  [{'id': 'nd001abf4', 'label': 'MMET429 Mgmt Pe...
#
#                                                 publications  \
# api_id
# n28cb7333  [{'id': 'n92740SE', 'label': 'Examining First-...
# n014c3d0f  [{'id': 'n87623SE', 'label': 'An autonomous ci...
# n7a168a93  [{'id': 'n367780SE', 'label': 'Effects of etha...
# nbccd1f64  [{'id': 'n317155SE', 'label': 'Four teaching s...
# n18de9127  [{'id': 'n83617SE', 'label': 'Detection and pr...
# ...                                                      ...
# nc1e62471  [{'id': 'n93579SE', 'label': 'A duplex real-ti...
# n14b2580b  [{'id': 'n589414SE', 'label': 'Catalysis of tr...
# n4f37dfa5  [{'id': 'n596137SE', 'label': 'Who Is a Rebel?...
# n0e788fcb                                                 []
# nca549702  [{'id': 'n605879SE', 'label': 'The design and ...
#
#                                                     hr_title  \
# api_id
# n28cb7333                       Clinical Assistant Professor
# n014c3d0f                  Instructional Associate Professor
# n7a168a93                  Instructional Assistant Professor
# nbccd1f64  Senior Associate Dean for Student Affairs and ...
# n18de9127                                Associate Professor
# ...                                                      ...
# nc1e62471                                       Section Head
# n14b2580b                            Postdoctoral Researcher
# n4f37dfa5                       Assistant Research Scientist
# n0e788fcb                       Clinical Assistant Professor
# nca549702                       Manager Technical Laboratory
#
#                                                all_positions  \
# api_id
# n28cb7333  [{'id': 'ne69a2757', 'label': 'Assistant Profe...
# n014c3d0f  [{'id': 'n073b4eaf', 'label': 'Associate Profe...
# n7a168a93  [{'id': 'n87109373', 'label': 'Assistant Profe...
# nbccd1f64  [{'id': 'n2c80881d', 'label': 'Professor', 'ty...
# n18de9127                                                 []
# ...                                                      ...
# nc1e62471  [{'id': 'nf71ae86c', 'label': 'Section Head, M...
# n14b2580b  [{'id': 'n18641334', 'label': 'Postdoctoral Re...
# n4f37dfa5  [{'id': 'n13f7fe34', 'label': 'Assistant Resea...
# n0e788fcb  [{'id': 'n1d395815', 'label': 'Clinical Assist...
# nca549702  [{'id': 'n1eefdb07', 'label': 'Lecturer', 'typ...
#
#                                                     overview
# api_id
# n28cb7333
# n014c3d0f  My primary research interest focuses on the un...
# n7a168a93  My recent research interests have focused on u...
# nbccd1f64  I am primarily a teaching faculty member and a...
# n18de9127  My laboratory works in two research areas. Fir...
# ...                                                      ...
# nc1e62471
# n14b2580b  Currently, working as a post doc and investiga...
# n4f37dfa5
# n0e788fcb
# nca549702
#
# [4859 rows x 17 columns]

# %%
people.to_pickle('../../Data/Scholars@TAMU/my_api_calls/people_df.pickle')

# %% [markdown]
# ## departments
#
# columns for departments
# metadata -> name, id, research fields

# %% [markdown]
# ## publications

# %%
publications = data['publications_overview'].copy()
publications['people_api_id'] = publications['people_api'].apply(lambda x: x.replace('https://api.library.tamu.edu/scholars-discovery/individual/', ''))
publications['publication_api_id'] = publications['publication_api'].apply(lambda x: x.replace('https://api.library.tamu.edu/scholars-discovery/individual/', ''))

publications_unified = pd.DataFrame({
    'author_ids': publications.groupby('publication_api_id')['people_api_id'].apply(list),
    'author_uins': publications.groupby('publication_api_id')['uin'].apply(list),
    'year': publications.groupby('publication_api_id')['year'].first(),
    'publication_type': publications.groupby('publication_api_id')['publication_type'].first(),
    'publication_title': publications.groupby('publication_api_id')['publication_title'].first()
})

# %%
pubs_wos = data['publications_subject_journal_wos'].copy()
pubs_wos['publication_api_id'] = pubs_wos['publication_api'].apply(lambda x: x.replace('https://api.library.tamu.edu/scholars-discovery/individual/', ''))

pubs_wos_unified = pd.DataFrame({
    'keyword': pubs_wos.groupby('publication_api_id')['keyword'].apply(list)
    })

# %%
unsdg = data['publications_unsdg'].copy()
unsdg['publication_api_id'] = unsdg['publication_api'].apply(lambda x: x.replace('https://api.library.tamu.edu/scholars-discovery/individual/', ''))

unsdg_unified = pd.DataFrame({
    'un_sustainable_development_goals': unsdg.groupby('publication_api_id')['name'].apply(list)
    })

# %%
authors = data['publications_author_institutions'].copy()
authors['publication_api_id'] = authors['publication_api'].apply(lambda x: x.replace('https://api.library.tamu.edu/scholars-discovery/individual/', ''))

authors_unified = pd.DataFrame({
    'author_organization': authors.groupby('publication_api_id')['organisation'].apply(list),
    'author_city': authors.groupby('publication_api_id')['city'].apply(list),
    'author_country': authors.groupby('publication_api_id')['country'].apply(list),
    })

# %%
abstract = data['publications_abstract'].copy()
abstract['publication_api_id'] = abstract['publication_api'].apply(lambda x: x.replace('https://api.library.tamu.edu/scholars-discovery/individual/', ''))

abstract_unified = pd.DataFrame({
    'abstract': abstract.groupby('publication_api_id')['abstract'].first()
    })

# %%
key = authors['publication_api_id'].sample(1).to_list()[0]

print('publication_api_id: ' + key)
display(publications[publications['publication_api_id'] == key])
display(pubs_wos[pubs_wos['publication_api_id'] == key])
display(unsdg[unsdg['publication_api_id'] == key])
display(authors[authors['publication_api_id'] == key])
display(abstract[abstract['publication_api_id'] == key])
# Out:
# publication_api_id: n301830SE
#                               people_uid        uin  \
# 187742  29c4db01cbc04b27820afdd347f0ab11  726000577
#
#                                                people_uri  \
# 187742  https://scholars.library.tamu.edu/vivo/display...
#
#                                                people_api  dept_id  \
# 187742  https://api.library.tamu.edu/scholars-discover...       16
#
#        publication_uid                                    publication_uri  \
# 187742        301830SE  https://scholars.library.tamu.edu/vivo/display...
#
#                                           publication_api  \
# 187742  https://api.library.tamu.edu/scholars-discover...
#
#                                   doi       issn  ...  year  \
# 187742  10.1128/CDLI.7.1.114-118.2000  1071-412X  ...  2000
#
#                                                begin_page  \
# 187742  0          388\n1          r40\n2          829...
#
#                                                  end_page  \
# 187742  0          394\n1          r40\n2          838...
#
#                                                    volume  \
# 187742  0         155\n1          12\n2           4\n3...
#
#                                                     issue  \
# 187742  0         NaN\n1           4\n2           6\n3...
#
#                                 publisher publication_type  \
# 187742  American Society for Microbiology  Journal Article
#
#                                         publication_title people_api_id  \
# 187742  Characterization of specific immune responses ...     n5889f585
#
#        publication_api_id
# 187742          n301830SE
#
# [1 rows x 23 columns]
#                                           publication_uri  \
# 100629  https://scholars.library.tamu.edu/vivo/display...
# 100630  https://scholars.library.tamu.edu/vivo/display...
# 100631  https://scholars.library.tamu.edu/vivo/display...
#
#                                           publication_api  \
# 100629  https://api.library.tamu.edu/scholars-discover...
# 100630  https://api.library.tamu.edu/scholars-discover...
# 100631  https://api.library.tamu.edu/scholars-discover...
#
#                      wos_id  wos_research_area_id              keyword  \
# 100629  WOS:000084723000023                35.000           Immunology
# 100630  WOS:000084723000023                36.000  Infectious Diseases
# 100631  WOS:000084723000023                37.000         Microbiology
#
#        publication_api_id
# 100629          n301830SE
# 100630          n301830SE
# 100631          n301830SE
# Empty DataFrame
# Columns: [publication_uri, publication_api, category_sdg_id, name, publication_api_id]
# Index: []
#                                           publication_uri  \
# 693552  https://scholars.library.tamu.edu/vivo/display...
#
#                                           publication_api  \
# 693552  https://api.library.tamu.edu/scholars-discover...
#
#                                       organisation          city    country  \
# 693552  National Agricultural Technology Institute  Buenos Aires  Argentina
#
#        publication_api_id
# 693552          n301830SE
#                                          publication_uri  \
# 93239  https://scholars.library.tamu.edu/vivo/display...
#
#                                          publication_api  \
# 93239  https://api.library.tamu.edu/scholars-discover...
#
#                                                 abstract publication_api_id
# 93239  Using the shuttle vector pMCO2 and the vaccini...          n301830SE

# %%
pubs_unified = pd.concat([publications_unified, pubs_wos_unified, unsdg_unified, authors_unified, abstract_unified], axis=1)

pubs_unified.sample(n=10)
# Out:
#                      author_ids  author_uins  year publication_type  \
# publication_api_id
# n43668SE            [n06bf3bf8]  [501001957]  1983  Journal Article
# n105384SE           [n238242e1]  [226003814]  2014    Working Paper
# n335694SE                   NaN          NaN   NaN              NaN
# n170405SE           [n35757a82]  [101009288]  1985  Journal Article
# n42398SE            [nd695d1d9]  [917000989]  2006  Journal Article
# n227606SE           [n939257d5]  [802005810]  2015             Book
# n196684SE           [n01799b2e]  [202008097]  1998  Journal Article
# n61122SE            [nb82a0bc7]  [814001818]  2014  Journal Article
# n120003SE           [n82bca37a]  [224005011]  1995  Journal Article
# n351210SE           [n2d08218e]  [818002449]  2020  Journal Article
#
#                                                     publication_title  \
# publication_api_id
# n43668SE            Homogeneous catalysts for carbon dioxide/hydro...
# n105384SE           Gender Differences in Competitiveness: The Rol...
# n335694SE                                                         NaN
# n170405SE           A Method for Investigation of Steady State Wav...
# n42398SE            Microarray Applications in Microbial Ecology R...
# n227606SE           Radioâ€Frequency Integratedâ€Circuit Enginee...
# n196684SE           Heat/Mass Transfer Distribution in a Rotating ...
# n61122SE            CO adsorption on Pt clusters supported on grap...
# n120003SE           Methods for Collecting, Processing, and Provid...
# n351210SE           A Power-of-Two Choices Based Algorithm for Fog...
#
#                                            keyword  \
# publication_api_id
# n43668SE                               [Chemistry]
# n105384SE                                      NaN
# n335694SE                                      NaN
# n170405SE           [Engineering, Water Resources]
# n42398SE                                       NaN
# n227606SE                                      NaN
# n196684SE                                      NaN
# n61122SE             [Chemistry, Electrochemistry]
# n120003SE                                      NaN
# n351210SE                       [Computer Science]
#
#                    un_sustainable_development_goals  \
# publication_api_id
# n43668SE                                        NaN
# n105384SE                                       NaN
# n335694SE                                       NaN
# n170405SE                                       NaN
# n42398SE                                        NaN
# n227606SE                                       NaN
# n196684SE                                       NaN
# n61122SE                                        NaN
# n120003SE                                       NaN
# n351210SE                                       NaN
#
#                                                   author_organization  \
# publication_api_id
# n43668SE                                   [Texas A and M University]
# n105384SE                                      [University of Zurich]
# n335694SE                  [University of Oklahoma, Drake University]
# n170405SE                                       [University of Maine]
# n42398SE                              [Oak Ridge National Laboratory]
# n227606SE                                                         NaN
# n196684SE                                  [Texas A and M University]
# n61122SE                                   [Texas A and M University]
# n120003SE                                                         NaN
# n351210SE           [Universita degli Studi di Roma La Sapienza, T...
#
#                                                           author_city  \
# publication_api_id
# n43668SE                                            [College Station]
# n105384SE                                                    [Zurich]
# n335694SE                                        [Norman, Des Moines]
# n170405SE                                                     [Orono]
# n42398SE                                                  [Oak Ridge]
# n227606SE                                                         NaN
# n196684SE                                           [College Station]
# n61122SE                                            [College Station]
# n120003SE                                                         NaN
# n351210SE           [Roma, Doha, College Station, Rome, Rome, Doha...
#
#                                                        author_country  \
# publication_api_id
# n43668SE                                              [United States]
# n105384SE                                               [Switzerland]
# n335694SE                              [United States, United States]
# n170405SE                                             [United States]
# n42398SE                                              [United States]
# n227606SE                                                         NaN
# n196684SE                                             [United States]
# n61122SE                                              [United States]
# n120003SE                                                         NaN
# n351210SE           [Italy, Qatar, United States, Italy, Italy, Qa...
#
#                                                              abstract
# publication_api_id
# n43668SE                                                         None
# n105384SE           Gender differences in competitiveness have bee...
# n335694SE                                                         NaN
# n170405SE           A technique is presented for modeling the evol...
# n42398SE            Microarray technology has the unparalleled pot...
# n227606SE           Â© 2015 by John Wiley  &  Sons, Inc. All right...
# n196684SE           Naphthalene sublimation experiments have been ...
# n61122SE            Density functional theory calculations are use...
# n120003SE                                                        None
# n351210SE           IEEE The fog computing paradigm brings togethe...

# %%
pubs_unified.to_pickle('../../Data/Scholars@TAMU/my_api_calls/publications_df.pickle')
