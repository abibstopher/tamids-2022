# %% [markdown]
# # Pulling in More Data from Scholars@TAMU
# **Filename:** pulling_more_data.ipynb
# **Path:** TAMIDS/Code/Scholars@TAMU Data/pulling_more_data.ipynb
# **Created Date:** 03 April 2022, 22:07
#
# There were some things missing from the provided data that I needed. I am making API calls to get get information like:
# - Department Name (not ID)
# -

# %%
from IPython.display import Markdown, display, HTML
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import json
import requests
from requests.exceptions import HTTPError
from tqdm import tqdm

pd.options.display.float_format = '{:,.3f}'.format
plt.style.use('seaborn-darkgrid')

# General Markdown Formatting Functions

def printmd(string, level=1):
    header_level = '#'*level + ' '
    display(Markdown(header_level + string))

# %% [markdown]
# ## DataFrame Preperation
#
# Creates a dictionary of dictionaries of dataframes for all the pickeled data.
# Ex: `data['people_education']` contains the 'people_education' DataFrame loaded from `../../Data/Scholars@TAMU/people/people_education.pickle`.
# This makes calls to each DataFrame simpler than they were in the `pickling_raw_data.ipynb` and `completeness.ipynb` files.

# %%
base_path = "../../Data/Scholars@TAMU"

with open('dicts/data_filenames.json', 'r') as infile:
    data_filenames = json.load(infile)

data = {}
for foldername, filenames in data_filenames.items():
    for filename in filenames:
        data[filename] = pd.read_pickle(base_path + "/" + foldername + "/" + filename + ".pickle")

# %% [markdown]
# ## Getting API URLs

# %%
apis = data['people_overview']['people_api'].unique()

apis
# Out:
# array(['https://api.library.tamu.edu/scholars-discovery/individual/n28cb7333',
#        'https://api.library.tamu.edu/scholars-discovery/individual/n014c3d0f',
#        'https://api.library.tamu.edu/scholars-discovery/individual/n7a168a93',
#        ...,
#        'https://api.library.tamu.edu/scholars-discovery/individual/n4f37dfa5',
#        'https://api.library.tamu.edu/scholars-discovery/individual/n0e788fcb',
#        'https://api.library.tamu.edu/scholars-discovery/individual/nca549702'],
#       dtype=object)

# %% [markdown]
# ## API Calls

# %%
def get_api_dict(url: str) -> dict:
    try:
        response = requests.get(url)
        response.raise_for_status()
        jsonResponse = response.json()
    except HTTPError as http_err:
        print(f'HTTP error occurred: {http_err}')
    except Exception as err:
        print(f'Other error occurred: {err}')
    else:
        return jsonResponse
    return {}

# %% [markdown]
# ### test case

# %%
url = 'https://api.library.tamu.edu/scholars-discovery/individual/n029092b0'
get_api_dict(url)
# Out:
# {'id': 'n029092b0',
#  'class': 'Person',
#  'name': 'Garay, Juan',
#  'primaryEmail': 'garay@tamu.edu',
#  'preferredTitle': 'Professor - Term Appointment',
#  'positions': [{'id': 'n0863ed82',
#    'label': 'Professor - Term Appointment',
#    'type': 'FacultyPosition',
#    'organizations': [{'id': 'n3b8431fc',
#      'label': 'Computer Science and Engineering',
#      'parent': [{'id': 'n8627320c', 'label': 'College of Engineering'}]}]}],
#  'overview': "Dr. Garay's research interests include both foundational and applied aspects of cryptography and information security. He has published extensively in the areas of cryptography, network security, distributed computing and algorithms. He has been involved in the design, analysis and implementation of a variety of secure systems, and is the recipient of over two dozen patents.",
#  'hrJobTitle': 'Professor',
#  'keywords': ['Perennial Computation',
#   'Secret Sharing',
#   'Oblivious Turing-machine',
#   'Information-theoretic Security',
#   'Cs.dc',
#   'Cs.dm',
#   'Cs.ds',
#   'Cs.db',
#   'Cs.ir',
#   'F.2,c.2,e,1,d.4.4',
#   'Cs.cc',
#   'Cryptographic Implementations',
#   'Garbled Circuits',
#   'Oblivious Transfer',
#   'Secure Multi-party Computation'],
#  'educationAndTraining': [{'id': 'n029092b0_572461c2-b39a-11e9-adb7-00155d9b610c_730827c3',
#    'label': 'EducationalProcess',
#    'name': 'Ph.D. Doctor of Philosophy',
#    'organization': {'id': 'n572461c2-b39a-11e9-adb7-00155d9b610c',
#     'label': 'Pennsylvania State University - (State College, Pennsylvania, United States)'},
#    'field': 'Computer Science',
#    'abbreviation': 'Ph.D.',
#    'endDate': '1989-01-01T00:00:00'}],
#  'publications': [{'id': 'n325469SE',
#    'label': 'A little honesty goes a long way: The two-tier model for secure multiparty computation',
#    'type': 'ConferencePaper',
#    'publicationDate': '2015-01-01T00:00:00',
#    'venue': {}},
#   {'id': 'n325503SE',
#    'label': 'Towards efficient private distributed computation on unbounded input streams',
#    'type': 'AcademicArticle',
#    'publicationDate': '2015-01-01T11:11:11',
#    'publisher': 'Walter de Gruyter GmbH',
#    'venue': {}},
#   {'id': 'n325612SE',
#    'label': 'Call Preemption in Communication Networks.',
#    'type': 'ConferencePaper',
#    'publicationDate': '1992-01-01T11:11:11'},
#   {'id': 'n325578SE',
#    'label': 'Abuse-Free Multi-party Contract Signing.',
#    'type': 'ConferencePaper',
#    'publicationDate': '1999-01-01T11:11:11'},
#   {'id': 'n325475SE',
#    'label': 'Efficient and Universally Composable Committed Oblivious Transfer and Applications',
#    'type': 'AcademicArticle',
#    'publicationDate': '2004-12-01T00:00:00',
#    'venue': {}},
#   {'id': 'n325606SE',
#    'label': 'Fast consensus in networks of bounded degree',
#    'type': 'AcademicArticle',
#    'publicationDate': '1993-12-01T00:00:00',
#    'publisher': 'Springer Science and Business Media LLC',
#    'venue': {}},
#   {'id': 'n325555SE',
#    'label': 'Information Security, 10th International Conference, ISC 2007, Valparaíso, Chile, October 9-12, 2007, Proceedings',
#    'type': 'ConferencePaper',
#    'publicationDate': '2007-01-01T11:11:11',
#    'publisher': 'Springer'},
#   {'id': 'n325603SE',
#    'label': 'iKP - A Family of Secure Electronic Payment Protocols.',
#    'type': 'ConferencePaper',
#    'publicationDate': '1995-01-01T11:11:11'},
#   {'id': 'n325569SE',
#    'label': 'On-line Admission Control and Packet Scheduling with Interleaving.',
#    'type': 'ConferencePaper',
#    'publicationDate': '2002-01-01T11:11:11'},
#   {'id': 'n325481SE',
#    'label': 'Design, implementation, and deployment of the iKP secure electronic payment system',
#    'type': 'AcademicArticle',
#    'publicationDate': '2000-04-01T00:00:00',
#    'publisher': 'Institute of Electrical and Electronics Engineers (IEEE)',
#    'venue': {}},
#   {'id': 'n325584SE',
#    'label': 'Adaptability and the Usefulness of Hints (Extended Abstract).',
#    'type': 'ConferencePaper',
#    'publicationDate': '1998-01-01T11:11:11'},
#   {'id': 'n325615SE',
#    'label': 'Optimal Amortized Distributed Consensus (Extended Abstract).',
#    'type': 'ConferencePaper',
#    'publicationDate': '1991-01-01T11:11:11'},
#   {'id': 'n325506SE',
#    'label': 'How Fair is Your Protocol?: A Utility-based Approach to Protocol Optimality.',
#    'type': 'ConferencePaper',
#    'publicationDate': '2015-01-01T11:11:11'},
#   {'id': 'n325493SE',
#    'label': 'MAC Precomputation with Applications to Secure Memory',
#    'type': 'AcademicArticle',
#    'publicationDate': '2016-01-01T11:11:11',
#    'publisher': 'Association for Computing Machinery (ACM)',
#    'venue': {}},
#   {'id': 'n325575SE',
#    'label': 'Application-Independent End-to-End Security in Shared-Link Access Networks.',
#    'type': 'ConferencePaper',
#    'publicationDate': '2000-01-01T11:11:11'},
#   {'id': 'n325466SE',
#    'label': 'Self-testing/correcting protocols',
#    'type': 'ConferencePaper',
#    'publicationDate': '1999-01-01T00:00:00',
#    'venue': {}},
#   {'id': 'n325472SE',
#    'label': 'Mutual search',
#    'type': 'AcademicArticle',
#    'publicationDate': '1999-07-01T00:00:00',
#    'publisher': 'Association for Computing Machinery (ACM)',
#    'venue': {}},
#   {'id': 'n325596SE',
#    'label': 'Fast, Long-Lived Renaming Improved and Simplified.',
#    'type': 'ConferencePaper',
#    'publicationDate': '1996-01-01T11:11:11'},
#   {'id': 'n325558SE',
#    'label': 'Round-Optimal and Efficient Verifiable Secret Sharing.',
#    'type': 'ConferencePaper',
#    'publicationDate': '2006-01-01T11:11:11'},
#   {'id': 'n325537SE',
#    'label': 'Adaptively secure broadcast, revisited.',
#    'type': 'ConferencePaper',
#    'publicationDate': '2011-01-01T11:11:11'},
#   {'id': 'n325512SE',
#    'label': 'Advances in Cryptology - CRYPTO 2014 - 34th Annual Cryptology Conference, Santa Barbara, CA, USA, August 17-21, 2014, Proceedings, Part I',
#    'type': 'ConferencePaper',
#    'publicationDate': '2014-01-01T11:11:11',
#    'publisher': 'Springer'},
#   {'id': 'n325564SE',
#    'label': 'Efficient authentication and key distribution in wireless IP networks',
#    'type': 'AcademicArticle',
#    'publicationDate': '2003-12-01T00:00:00',
#    'publisher': 'Institute of Electrical and Electronics Engineers (IEEE)',
#    'venue': {}},
#   {'id': 'n325621SE',
#    'label': 'Efficient Agreement on Bounded-Degree Networks.',
#    'type': 'ConferencePaper',
#    'publicationDate': '1989-01-01T11:11:11'},
#   {'id': 'n325600SE',
#    'label': 'Long-Lived Renaming Made Fast.',
#    'type': 'ConferencePaper',
#    'publicationDate': '1995-01-01T11:11:11'},
#   {'id': 'n325618SE',
#    'label': 'Analysis of block-paging strategies',
#    'type': 'AcademicArticle',
#    'publicationDate': '1989-01-01T00:00:00',
#    'publisher': 'IBM',
#    'venue': {}},
#   {'id': 'n325486SE',
#    'label': 'The Price of Low Communication in Secure Multi-party Computation.',
#    'type': 'ConferencePaper',
#    'publicationDate': '2017-01-01T11:11:11'},
#   {'id': 'n325581SE',
#    'label': 'A security architecture for the Internet Protocol',
#    'type': 'AcademicArticle',
#    'publicationDate': '1998-01-01T00:00:00',
#    'publisher': 'IBM',
#    'venue': {}},
#   {'id': 'n325543SE',
#    'label': 'Somewhat Non-committing Encryption and Efficient Adaptively Secure Oblivious Transfer.',
#    'type': 'ConferencePaper',
#    'publicationDate': '2009-01-01T11:11:11'},
#   {'id': 'n325526SE',
#    'label': 'Edge Fault Tolerance on Sparse Networks.',
#    'type': 'ConferencePaper',
#    'publicationDate': '2012-01-01T11:11:11'},
#   {'id': 'n325614SE',
#    'label': 'Optimal Early Stopping in Distributed Consensus (Extended Abstract).',
#    'type': 'ConferencePaper',
#    'publicationDate': '1992-01-01T11:11:11'},
#   {'id': 'n325599SE',
#    'label': 'Optimal Resiliency against Mobile Faults.',
#    'type': 'ConferencePaper',
#    'publicationDate': '1995-01-01T11:11:11'},
#   {'id': 'n325467SE',
#    'label': 'Almost-Everywhere Secure Computation with Edge Corruptions',
#    'type': 'AcademicArticle',
#    'publicationDate': '2013-12-01T00:00:00',
#    'publisher': 'Springer Science and Business Media LLC',
#    'venue': {},
#    'tags': '16 Peace, Justice and Strong Institutions'},
#   {'id': 'n325473SE',
#    'label': 'Sharing video on demand',
#    'type': 'ConferencePaper',
#    'publicationDate': '2003-06-01T00:00:00',
#    'publisher': 'Elsevier bv',
#    'venue': {}},
#   {'id': 'n325604SE',
#    'label': 'Adaptive Video on Demand.',
#    'type': 'ConferencePaper',
#    'publicationDate': '1994-01-01T11:11:11'},
#   {'id': 'n325557SE',
#    'label': 'Searchable symmetric encryption: improved definitions and efficient constructions.',
#    'type': 'ConferencePaper',
#    'publicationDate': '2006-01-01T11:11:11'},
#   {'id': 'n325572SE',
#    'label': 'MicroISPs: providing convenient and low-cost high-bandwidth Internet access',
#    'type': 'AcademicArticle',
#    'publicationDate': '2000-06-01T00:00:00',
#    'publisher': 'Elsevier bv',
#    'venue': {}},
#   {'id': 'n325518SE',
#    'label': 'Rational Protocol Design: Cryptography against Incentive-Driven Adversaries.',
#    'type': 'ConferencePaper',
#    'publicationDate': '2013-01-01T11:11:11'},
#   {'id': 'n325586SE',
#    'label': 'Batch Verification with Applications to Cryptography and Checking.',
#    'type': 'ConferencePaper',
#    'publicationDate': '1998-01-01T11:11:11'},
#   {'id': 'n325592SE',
#    'label': 'Competing against Specialists.',
#    'type': 'ConferencePaper',
#    'publicationDate': '1997-01-01T11:11:11'},
#   {'id': 'n325620SE',
#    'label': 'Asymptotically Optimal Distributed Consensus (Extended Abstract).',
#    'type': 'ConferencePaper',
#    'publicationDate': '1989-01-01T11:11:11'},
#   {'id': 'n325601SE',
#    'label': 'Securing the Internet (Abstract).',
#    'type': 'ConferencePaper',
#    'publicationDate': '1995-01-01T11:11:11'},
#   {'id': 'n345997SE',
#    'label': 'Bootstrapping the Blockchain, with Applications to Consensus and Fast PKI Setup',
#    'type': 'ConferencePaper',
#    'publicationDate': '2018-03-01T00:00:00',
#    'publisher': 'Springer International Publishing',
#    'venue': {}},
#   {'id': 'n325487SE',
#    'label': 'Round-Preserving Parallel Composition of Probabilistic-Termination Cryptographic Protocols.',
#    'type': 'ConferencePaper',
#    'publicationDate': '2017-01-01T11:11:11'},
#   {'id': 'n325617SE',
#    'label': 'Fast Consensus in Networks of Bounded Degree (Extended Abstract).',
#    'type': 'ConferencePaper',
#    'publicationDate': '1990-01-01T11:11:11'},
#   {'id': 'n325544SE',
#    'label': 'MAC Precomputation with Applications to Secure Memory.',
#    'type': 'ConferencePaper',
#    'publicationDate': '2009-01-01T11:11:11'},
#   {'id': 'n325521SE',
#    'label': 'Advances in Cryptology - CRYPTO 2013 - 33rd Annual Cryptology Conference, Santa Barbara, CA, USA, August 18-22, 2013. Proceedings, Part I',
#    'type': 'ConferencePaper',
#    'publicationDate': '2013-01-01T11:11:11',
#    'publisher': 'Springer'},
#   {'id': 'n325577SE',
#    'label': 'Multicast Security: A Taxonomy and Some Efficient Constructions.',
#    'type': 'ConferencePaper',
#    'publicationDate': '1999-01-01T11:11:11'},
#   {'id': 'n325470SE',
#    'label': 'On the Complexity of UC Commitments',
#    'type': 'ConferencePaper',
#    'publicationDate': '2014-01-01T00:00:00',
#    'publisher': 'Springer Berlin Heidelberg',
#    'venue': {}},
#   {'id': 'n325527SE',
#    'label': 'Brief Announcement: Efficient Private Distributed Computation on Unbounded Input Streams.',
#    'type': 'ConferencePaper',
#    'publicationDate': '2012-01-01T11:11:11'},
#   {'id': 'n325504SE',
#    'label': 'The Bitcoin Backbone Protocol: Analysis and Applications.',
#    'type': 'ConferencePaper',
#    'publicationDate': '2015-01-01T11:11:11'},
#   {'id': 'n325495SE',
#    'label': 'Probabilistic Termination and Composability of Cryptographic Protocols.',
#    'type': 'ConferencePaper',
#    'publicationDate': '2016-01-01T11:11:11'},
#   {'id': 'n325609SE',
#    'label': 'Randomized Distributed Agreement Revisited.',
#    'type': 'ConferencePaper',
#    'publicationDate': '1993-01-01T11:11:11'},
#   {'id': 'n325464SE',
#    'label': 'Long-lived broadcast encryption',
#    'type': 'ConferencePaper',
#    'publicationDate': '2000-01-01T00:00:00',
#    'venue': {}},
#   {'id': 'n325510SE',
#    'label': 'Secure Message Transmission With Small Public Discussion',
#    'type': 'AcademicArticle',
#    'publicationDate': '2014-02-01T00:00:00',
#    'publisher': 'Institute of Electrical and Electronics Engineers (IEEE)',
#    'venue': {}},
#   {'id': 'n325535SE',
#    'label': 'Secure Message Transmission by Public Discussion: A Brief Survey.',
#    'type': 'ConferencePaper',
#    'publicationDate': '2011-01-01T11:11:11'},
#   {'id': 'n213077SE',
#    'label': 'Preface',
#    'type': 'Book',
#    'publicationDate': '2004-06-01T00:00:00',
#    'publisher': 'Elsevier bv'},
#   {'id': 'n382948SE',
#    'label': 'Perennial secure multi-party computation of universal Turing machine',
#    'type': 'AcademicArticle',
#    'publicationDate': '2019-05-01T00:00:00',
#    'publisher': 'Elsevier bv',
#    'venue': {}},
#   {'id': 'n325538SE',
#    'label': 'A Framework for the Sound Specification of Cryptographic Tasks.',
#    'type': 'ConferencePaper',
#    'publicationDate': '2010-01-01T11:11:11'},
#   {'id': 'n325623SE',
#    'label': 'Preliminary Analysis of Page Reference Strings of an Interactive System.',
#    'type': 'ConferencePaper',
#    'publicationDate': '1985-01-01T11:11:11'},
#   {'id': 'n325478SE',
#    'label': 'Software integrity protection using timed executable agents',
#    'type': 'ConferencePaper',
#    'publicationDate': '2006-01-01T00:00:00',
#    'publisher': 'ACM Press'},
#   {'id': 'n325484SE',
#    'label': 'Efficient, Constant-Round and Actively Secure MPC',
#    'type': 'ConferencePaper',
#    'publicationDate': '2017-10-01T00:00:00',
#    'publisher': 'ACM',
#    'tags': '16 Peace, Justice and Strong Institutions'},
#   {'id': 'n325583SE',
#    'label': 'A SubLinear Time Distributed Algorithm for Minimum-Weight Spanning Trees',
#    'type': 'AcademicArticle',
#    'publicationDate': '1998-02-01T00:00:00',
#    'publisher': 'Society for Industrial & Applied Mathematics (SIAM)',
#    'venue': {}},
#   {'id': 'n325541SE',
#    'label': 'Brief announcement: swarming secrets.',
#    'type': 'ConferencePaper',
#    'publicationDate': '2010-01-01T11:11:11'},
#   {'id': 'n325507SE',
#    'label': 'Fair Distributed Computation of Reactive Functions.',
#    'type': 'ConferencePaper',
#    'publicationDate': '2015-01-01T11:11:11'},
#   {'id': 'n325494SE',
#    'label': 'Constant-Round Asynchronous Multi-Party Computation Based on One-Way Functions.',
#    'type': 'ConferencePaper',
#    'publicationDate': '2016-01-01T11:11:11'},
#   {'id': 'n325574SE',
#    'label': 'Concurrent Oblivious Transfer.',
#    'type': 'ConferencePaper',
#    'publicationDate': '2000-01-01T11:11:11'},
#   {'id': 'n548039SE',
#    'label': 'Consensus from Signatures of Work',
#    'type': 'ConferencePaper',
#    'publicationDate': '2020-01-01T11:11:11',
#    'publisher': 'Springer International Publishing',
#    'venue': {}},
#   {'id': 'n325471SE',
#    'label': 'Minimal complete primitives for secure multi-party computation',
#    'type': 'ConferencePaper',
#    'publicationDate': '2001-12-01T00:00:00',
#    'venue': {}},
#   {'id': 'n325597SE',
#    'label': 'Optimal Amortized Distributed Consensus',
#    'type': 'AcademicArticle',
#    'publicationDate': '1995-07-01T00:00:00',
#    'publisher': 'Elsevier bv',
#    'venue': {}},
#   {'id': 'n325465SE',
#    'label': 'Timed release of standard digital signatures extended abstract',
#    'type': 'ConferencePaper',
#    'publicationDate': '2003-01-01T00:00:00',
#    'venue': {}},
#   {'id': 'n325559SE',
#    'label': 'Resource Fairness and Composability of Cryptographic Protocols.',
#    'type': 'ConferencePaper',
#    'publicationDate': '2006-01-01T11:11:11'},
#   {'id': 'n325513SE',
#    'label': 'Advances in Cryptology - CRYPTO 2014 - 34th Annual Cryptology Conference, Santa Barbara, CA, USA, August 17-21, 2014, Proceedings, Part II',
#    'type': 'ConferencePaper',
#    'publicationDate': '2014-01-01T11:11:11',
#    'publisher': 'Springer'},
#   {'id': 'n325536SE',
#    'label': 'Secret Sharing Krohn-Rhodes: Private and Perennial Distributed Computation.',
#    'type': 'ConferencePaper',
#    'publicationDate': '2011-01-01T11:11:11'},
#   {'id': 'n325479SE',
#    'label': 'Strengthening zero-knowledge protocols using signatures',
#    'type': 'AcademicArticle',
#    'publicationDate': '2003-12-01T00:00:00',
#    'venue': {}},
#   {'id': 'n325622SE',
#    'label': 'Analysis of page-reference strings of an interactive system',
#    'type': 'AcademicArticle',
#    'publicationDate': '1988-07-01T00:00:00',
#    'publisher': 'IBM',
#    'venue': {}},
#   {'id': 'n325539SE',
#    'label': 'Secure Message Transmission with Small Public Discussion.',
#    'type': 'ConferencePaper',
#    'publicationDate': '2010-01-01T11:11:11'},
#   {'id': 'n325485SE',
#    'label': 'The Bitcoin Backbone Protocol with Chains of Variable Difficulty.',
#    'type': 'ConferencePaper',
#    'publicationDate': '2017-01-01T11:11:11'},
#   {'id': 'n325594SE',
#    'label': 'Fast, Long-Lived Renaming Improved and Simplified (Abstract).',
#    'type': 'ConferencePaper',
#    'publicationDate': '1996-01-01T11:11:11'},
#   {'id': 'n325588SE',
#    'label': 'VarietyCash: A Multi-Purpose Electronic Payment System.',
#    'type': 'ConferencePaper',
#    'publicationDate': '1998-01-01T11:11:11'},
#   {'id': 'n325619SE',
#    'label': 'Towards Optimal Distributed Consensus (Extended Abstract)',
#    'type': 'ConferencePaper',
#    'publicationDate': '1989-01-01T11:11:11'},
#   {'id': 'n325542SE',
#    'label': 'Security and Cryptography for Networks, 7th International Conference, SCN 2010, Amalfi, Italy, September 13-15, 2010. Proceedings',
#    'type': 'ConferencePaper',
#    'publicationDate': '2010-01-01T11:11:11',
#    'publisher': 'Springer'},
#   {'id': 'n325611SE',
#    'label': 'Fully polynomial Byzantine agreement in t+1 rounds.',
#    'type': 'ConferencePaper',
#    'publicationDate': '1993-01-01T11:11:11'},
#   {'id': 'n325554SE',
#    'label': 'Towards Optimal and Efficient Perfectly Secure Message Transmission.',
#    'type': 'ConferencePaper',
#    'publicationDate': '2007-01-01T11:11:11'},
#   {'id': 'n325579SE',
#    'label': 'Self-Testing/Correcting Protocols (Extended Abstract).',
#    'type': 'ConferencePaper',
#    'publicationDate': '1999-01-01T11:11:11'},
#   {'id': 'n325476SE',
#    'label': 'Efficient Player-Optimal Protocols for Strong and Differential Consensus',
#    'type': 'ConferencePaper',
#    'publicationDate': '2003-12-01T00:00:00'},
#   {'id': 'n325607SE',
#    'label': 'Cloture Votes:n/4-resilient Distributed Consensus int + 1 rounds',
#    'type': 'AcademicArticle',
#    'publicationDate': '1993-01-01T00:00:00',
#    'publisher': 'Springer Science and Business Media LLC',
#    'venue': {}},
#   {'id': 'n325519SE',
#    'label': 'Broadcast (and Round) Efficient Verifiable Secret Sharing.',
#    'type': 'ConferencePaper',
#    'publicationDate': '2013-01-01T11:11:11'},
#   {'id': 'n325533SE',
#    'label': 'Searchable symmetric encryption: Improved definitions and efficient constructions',
#    'type': 'AcademicArticle',
#    'publicationDate': '2011-11-01T00:00:00',
#    'publisher': 'IOS Press',
#    'venue': {}},
#   {'id': 'n325591SE',
#    'label': 'Efficient On-Line Call Control Algorithms',
#    'type': 'AcademicArticle',
#    'publisher': 'Elsevier bv',
#    'venue': {}},
#   {'id': 'n325568SE',
#    'label': 'Timed Release of Standard Digital Signatures.',
#    'type': 'ConferencePaper',
#    'publicationDate': '2002-01-01T11:11:11'},
#   {'id': 'n325585SE',
#    'label': 'Fast Batch Verification for Modular Exponentiation and Digital Signatures.',
#    'type': 'ConferencePaper',
#    'publicationDate': '1998-01-01T11:11:11'},
#   {'id': 'n325482SE',
#    'label': 'Almost-Everywhere Secure Computation',
#    'type': 'ConferencePaper',
#    'publicationDate': '2008-01-01T00:00:00',
#    'publisher': 'Springer Berlin Heidelberg',
#    'venue': {}},
#   {'id': 'n325522SE',
#    'label': 'Advances in Cryptology - CRYPTO 2013 - 33rd Annual Cryptology Conference, Santa Barbara, CA, USA, August 18-22, 2013. Proceedings, Part II',
#    'type': 'ConferencePaper',
#    'publicationDate': '2013-01-01T11:11:11',
#    'publisher': 'Springer'},
#   {'id': 'n316007SE',
#    'label': 'Special Issue: Algorithmic Tools in Cryptography',
#    'type': 'AcademicArticle',
#    'publicationDate': '2017-08-01T00:00:00',
#    'publisher': 'Springer Science and Business Media LLC',
#    'venue': {}},
#   {'id': 'n325505SE',
#    'label': 'Blockchain-Based Consensus (Keynote).',
#    'type': 'ConferencePaper',
#    'publicationDate': '2015-01-01T11:11:11'},
#   {'id': 'n325576SE',
#    'label': 'Abuse-Free Optimistic Contract Signing.',
#    'type': 'ConferencePaper',
#    'publicationDate': '1999-01-01T11:11:11'},
#   {'id': 'n325553SE',
#    'label': 'Practical and Secure Solutions for Integer Comparison.',
#    'type': 'ConferencePaper',
#    'publicationDate': '2007-01-01T11:11:11'},
#   {'id': 'n325496SE',
#    'label': 'On the Implausibility of Constant-Round Public-Coin Zero-Knowledge Proofs.',
#    'type': 'ConferencePaper',
#    'publicationDate': '2016-01-01T11:11:11'},
#   {'id': 'n325610SE',
#    'label': 'Efficient On-Line Call Control Algorithms.',
#    'type': 'ConferencePaper',
#    'publicationDate': '1993-01-01T11:11:11'},
#   {'id': 'n325595SE',
#    'label': 'Distributed Pseudo-Random Bit Generators - A New Way to Speed-Up Shared Coin Tossing.',
#    'type': 'ConferencePaper',
#    'publicationDate': '1996-01-01T11:11:11'},
#   {'id': 'n325463SE',
#    'label': 'The Hidden Graph Model',
#    'type': 'ConferencePaper',
#    'publicationDate': '2015-01-01T00:00:00',
#    'publisher': 'ACM'},
#   {'id': 'n325534SE',
#    'label': 'Resource Fairness and Composability of Cryptographic Protocols',
#    'type': 'AcademicArticle',
#    'publicationDate': '2010-09-01T00:00:00',
#    'publisher': 'Springer Science and Business Media LLC',
#    'venue': {}},
#   {'id': 'n325511SE',
#    'label': 'Fast and unconditionally secure anonymous channel.',
#    'type': 'ConferencePaper',
#    'publicationDate': '2014-01-01T11:11:11'},
#   {'id': 'n325608SE',
#    'label': 'A Sub-Linear Time Distributed Algorithm for Minimum-Weight Spanning Trees (Extended Abstract)',
#    'type': 'ConferencePaper',
#    'publicationDate': '1993-01-01T11:11:11'},
#   {'id': 'n325567SE',
#    'label': 'A scheme for authentication and dynamic key exchange in wireless networks',
#    'type': 'AcademicArticle',
#    'publicationDate': '2002-06-01T00:00:00',
#    'publisher': 'Institute of Electrical and Electronics Engineers (IEEE)',
#    'venue': {}},
#   {'id': 'n325477SE',
#    'label': 'Minimal Complete Primitives for Secure Multi-Party Computation',
#    'type': 'AcademicArticle',
#    'publicationDate': '2004-04-01T00:00:00',
#    'publisher': 'Springer Science and Business Media LLC',
#    'venue': {}},
#   {'id': 'n325483SE',
#    'label': 'Round complexity of authenticated broadcast with a dishonest majority',
#    'type': 'ConferencePaper',
#    'publicationDate': '2007-12-01T00:00:00',
#    'publisher': 'IEEE',
#    'venue': {}},
#   {'id': 'n325582SE',
#    'label': 'Fully Polynomial Byzantine Agreement for n > 3t Processors in t + 1 Rounds',
#    'type': 'AcademicArticle',
#    'publicationDate': '1998-01-01T11:11:11',
#    'publisher': 'Society for Industrial & Applied Mathematics (SIAM)',
#    'venue': {}},
#   {'id': 'n325548SE',
#    'label': 'Partially Connected Networks: Information Theoretically Secure Protocols and Open Problems (Invited Talk).',
#    'type': 'ConferencePaper',
#    'publicationDate': '2008-01-01T11:11:11'},
#   {'id': 'n325540SE',
#    'label': 'Improved Fault Tolerance and Secure Computation on Sparse Networks.',
#    'type': 'ConferencePaper',
#    'publicationDate': '2010-01-01T11:11:11'},
#   {'id': 'n325468SE',
#    'label': 'Eyedecrypt—private interactions in plain sight',
#    'type': 'ConferencePaper',
#    'publicationDate': '2014-01-01T00:00:00',
#    'venue': {}},
#   {'id': 'n325613SE',
#    'label': 'A Continuum of Failure Models for Distributed Computing.',
#    'type': 'ConferencePaper',
#    'publicationDate': '1992-01-01T11:11:11'},
#   {'id': 'n325598SE',
#    'label': 'Adaptive Video on Demand.',
#    'type': 'ConferencePaper',
#    'publicationDate': '1995-01-01T11:11:11'},
#   {'id': 'n325474SE',
#    'label': 'Timed fair exchange of standard signatures [extended abstract]',
#    'type': 'AcademicArticle',
#    'publicationDate': '2003-12-01T00:00:00',
#    'venue': {}},
#   {'id': 'n325605SE',
#    'label': 'Reaching (and Maintaining) Agreement in the Presence of Mobile Faults (Extended Abstract).',
#    'type': 'ConferencePaper',
#    'publicationDate': '1994-01-01T11:11:11'},
#   {'id': 'n325573SE',
#    'label': 'Secure distributed storage and retrieval',
#    'type': 'AcademicArticle',
#    'publicationDate': '2000-07-01T00:00:00',
#    'publisher': 'Elsevier bv',
#    'venue': {}},
#   {'id': 'n325517SE',
#    'label': 'Towards Efficient Private Distributed Computation on Unbounded Input Streams - (Extended Abstract).',
#    'type': 'ConferencePaper',
#    'publicationDate': '2013-01-01T11:11:11'},
#   {'id': 'n325602SE',
#    'label': 'Design and Implementation of Modular Key Management Protocol and IP Secure Tunnel on AIX.',
#    'type': 'ConferencePaper',
#    'publicationDate': '1995-01-01T11:11:11'},
#   {'id': 'n325593SE',
#    'label': 'Secure Distributed Storage and Retrieval.',
#    'type': 'ConferencePaper',
#    'publicationDate': '1997-01-01T11:11:11'},
#   {'id': 'n325587SE',
#    'label': 'Mutual Search (Extended Abstract).',
#    'type': 'ConferencePaper',
#    'publicationDate': '1998-01-01T11:11:11'},
#   {'id': 'n325480SE',
#    'label': 'Strengthening Zero-Knowledge Protocols Using Signatures',
#    'type': 'AcademicArticle',
#    'publicationDate': '2005-12-01T00:00:00',
#    'publisher': 'Springer Science and Business Media LLC',
#    'venue': {}},
#   {'id': 'n325545SE',
#    'label': 'Cryptology and Network Security, 8th International Conference, CANS 2009, Kanazawa, Japan, December 12-14, 2009. Proceedings',
#    'type': 'ConferencePaper',
#    'publicationDate': '2009-01-01T11:11:11',
#    'publisher': 'Springer'},
#   {'id': 'n325616SE',
#    'label': 'Efficient Distributed Consensus with n = (3 + epsilon) t Processors (Extended Abstract).',
#    'type': 'ConferencePaper',
#    'publicationDate': '1991-01-01T11:11:11'},
#   {'id': 'n325488SE',
#    'label': 'Brief Announcement: Secure Self-Stabilizing Computation.',
#    'type': 'ConferencePaper',
#    'publicationDate': '2017-01-01T11:11:11'},
#   {'id': 'n325520SE',
#    'label': 'Resource-based corruptions and the combinatorics of hidden diversity.',
#    'type': 'ConferencePaper',
#    'publicationDate': '2013-01-01T11:11:11'}],
#  'researcherOn': [{'id': 'n19409404-38a1-11eb-bf18-005056bb4fb7',
#    'label': 'SaTC: CORE: Small: Collaborative: Exploring the Boundaries of Large-Scale Secure Computation',
#    'awardedBy': {'id': 'ne563cb6e-b3be-11e9-adb7-00155d9b610c',
#     'label': 'Directorate for Computer & Information Science & Engineering - (Arlington, Virginia, United States)'},
#    'role': 'PrincipalInvestigatorRole',
#    'startDate': '2020-01-01T00:00:00',
#    'endDate': '2023-01-01T00:00:00'}],
#  'teachingActivities': [{'id': 'n64168fd4',
#    'label': 'CSCE691 Research',
#    'role': 'Instructor'},
#   {'id': 'n32996c59',
#    'label': 'CSCE629 Analysis Of Algorithms',
#    'role': 'Instructor'},
#   {'id': 'ne0b55021',
#    'label': 'CSCE485 Directed Studies',
#    'role': 'Instructor'},
#   {'id': 'n1ba6a77b',
#    'label': 'CSCE685 Directed Studies',
#    'role': 'Instructor'},
#   {'id': 'n35b4cc2e',
#    'label': 'CSCE689 Sptp: Intro Modern Cryptograph',
#    'role': 'Instructor'},
#   {'id': 'nb2109700', 'label': 'CSCE491 Hnr-research', 'role': 'Instructor'},
#   {'id': 'nb2109700', 'label': 'CSCE491 Research', 'role': 'Instructor'},
#   {'id': 'ncc5a3c93',
#    'label': 'CSCE689 Sptp:blockchain Foundations',
#    'role': 'Instructor'},
#   {'id': 'n9a5a3efc',
#    'label': 'CSCE489 Sptp:intro Mdrn Crypto',
#    'role': 'Instructor'},
#   {'id': 'nd34177ca',
#    'label': 'CSCE489 Sptp:fndn In Mod Cryptography',
#    'role': 'Instructor'},
#   {'id': 'n050e7712',
#    'label': 'CSCE711 Foundation Modern Cryptography',
#    'role': 'Instructor'},
#   {'id': 'nefb84350',
#    'label': 'CSCE411 Design Analy Algorithms',
#    'role': 'Instructor'},
#   {'id': 'nba42ca56',
#    'label': 'CSCE684 Professional Internship:in Ab',
#    'role': 'Instructor'},
#   {'id': 'nba42ca56',
#    'label': 'CSCE684 Professional Internship:in-ab',
#    'role': 'Instructor'},
#   {'id': 'nba42ca56',
#    'label': 'CSCE684 Professional Internship: In-ab',
#    'role': 'Instructor'}],
#  'email': 'garay@tamu.edu',
#  'firstName': 'Juan',
#  'lastName': 'Garay',
#  'streetAddress': 'Texas A&M University; Computer Science & Engineering; 3112 TAMU',
#  'locality': 'College Station',
#  'region': 'TX',
#  'postalCode': '77843-3112',
#  'country': 'USA',
#  'organizations': ['Computer Science and Engineering'],
#  'schools': ['College of Engineering'],
#  'netid': 'garay',
#  'uid': 'c64acf45dcceb6a7c0573eeff40c0b35',
#  'featuredProfileDisplay': 'true',
#  'type': ['FacultyMember'],
#  'modTime': 'Tue Feb 15 17:31:56 UTC 2022',
#  '_links': {'self': {'href': 'https://api.library.tamu.edu/scholars-discovery/individual/n029092b0'},
#   'individual': {'href': 'https://api.library.tamu.edu/scholars-discovery/individual/n029092b0'}}}

# %% [markdown]
# ## General Data from all IDs

# %%
succesfull_calls = []
failed_calls = []

for api in tqdm(apis):
    response = get_api_dict(url=api)
    if response:
        succesfull_calls.append(response)
    else:
        failed_calls.append(api)
# Out:
#   8%|▊         | 391/4860 [02:22<24:02,  3.10it/s]
# HTTP error occurred: 404 Client Error:  for url: https://api.library.tamu.edu/scholars-discovery/individual/n531a30c4
#  14%|█▍        | 684/4860 [04:34<27:41,  2.51it/s]
# HTTP error occurred: 404 Client Error:  for url: https://api.library.tamu.edu/scholars-discovery/individual/n6b86bf0a
#  16%|█▌        | 777/4860 [05:07<21:05,  3.23it/s]
# HTTP error occurred: 404 Client Error:  for url: https://api.library.tamu.edu/scholars-discovery/individual/nb0ba8174
#  17%|█▋        | 830/4860 [05:25<23:32,  2.85it/s]
# Other error occurred: Invalid URL 'and cell wall assembly."': No scheme supplied. Perhaps you meant http://and cell wall assembly."?
#  22%|██▏       | 1077/4860 [06:56<20:53,  3.02it/s]
# HTTP error occurred: 404 Client Error:  for url: https://api.library.tamu.edu/scholars-discovery/individual/nb2af52ee
#  25%|██▌       | 1217/4860 [07:51<26:59,  2.25it/s]
# HTTP error occurred: 404 Client Error:  for url: https://api.library.tamu.edu/scholars-discovery/individual/n6fe482a6
#  26%|██▌       | 1247/4860 [08:01<20:38,  2.92it/s]
# HTTP error occurred: 404 Client Error:  for url: https://api.library.tamu.edu/scholars-discovery/individual/n14aa5202
#  33%|███▎      | 1587/4860 [10:01<16:42,  3.26it/s]
# HTTP error occurred: 404 Client Error:  for url: https://api.library.tamu.edu/scholars-discovery/individual/n3d197541
#  38%|███▊      | 1836/4860 [11:27<18:01,  2.80it/s]
# HTTP error occurred: 404 Client Error:  for url: https://api.library.tamu.edu/scholars-discovery/individual/n7b5179b3
#  40%|████      | 1960/4860 [12:12<16:58,  2.85it/s]
# HTTP error occurred: 404 Client Error:  for url: https://api.library.tamu.edu/scholars-discovery/individual/n847f3873
#  41%|████      | 1997/4860 [12:26<17:57,  2.66it/s]
# HTTP error occurred: 404 Client Error:  for url: https://api.library.tamu.edu/scholars-discovery/individual/n631e24a7
#  41%|████▏     | 2006/4860 [12:31<19:05,  2.49it/s]
# HTTP error occurred: 404 Client Error:  for url: https://api.library.tamu.edu/scholars-discovery/individual/n8247cf18
#  43%|████▎     | 2094/4860 [13:46<22:53,  2.01it/s]
# HTTP error occurred: 404 Client Error:  for url: https://api.library.tamu.edu/scholars-discovery/individual/n0e3856dd
#  45%|████▌     | 2198/4860 [14:47<14:09,  3.13it/s]
# HTTP error occurred: 404 Client Error:  for url: https://api.library.tamu.edu/scholars-discovery/individual/ne71697c4
#  48%|████▊     | 2333/4860 [15:36<14:42,  2.86it/s]
# HTTP error occurred: 404 Client Error:  for url: https://api.library.tamu.edu/scholars-discovery/individual/n3525e685
#  71%|███████▏  | 3470/4860 [22:12<08:30,  2.72it/s]
# HTTP error occurred: 404 Client Error:  for url: https://api.library.tamu.edu/scholars-discovery/individual/n1ab41bb2
#  76%|███████▌  | 3678/4860 [24:11<06:05,  3.23it/s]
# HTTP error occurred: 404 Client Error:  for url: https://api.library.tamu.edu/scholars-discovery/individual/na9655306
#  76%|███████▌  | 3684/4860 [24:13<06:12,  3.16it/s]
# HTTP error occurred: 404 Client Error:  for url: https://api.library.tamu.edu/scholars-discovery/individual/nf26d46a6
#  78%|███████▊  | 3789/4860 [24:46<05:17,  3.37it/s]
# HTTP error occurred: 404 Client Error:  for url: https://api.library.tamu.edu/scholars-discovery/individual/n981a6d1d
#  78%|███████▊  | 3815/4860 [24:54<05:08,  3.39it/s]
# HTTP error occurred: 404 Client Error:  for url: https://api.library.tamu.edu/scholars-discovery/individual/n87907ac0
#  79%|███████▉  | 3858/4860 [25:06<05:17,  3.16it/s]
# HTTP error occurred: 404 Client Error:  for url: https://api.library.tamu.edu/scholars-discovery/individual/nb2760449
#  80%|███████▉  | 3886/4860 [25:16<05:00,  3.24it/s]
# HTTP error occurred: 404 Client Error:  for url: https://api.library.tamu.edu/scholars-discovery/individual/ncbe3c229
#  82%|████████▏ | 3989/4860 [25:48<04:28,  3.24it/s]
# HTTP error occurred: 404 Client Error:  for url: https://api.library.tamu.edu/scholars-discovery/individual/n4be06dfb
#  83%|████████▎ | 4018/4860 [25:57<04:38,  3.02it/s]
# HTTP error occurred: 404 Client Error:  for url: https://api.library.tamu.edu/scholars-discovery/individual/n63a8f154
#  84%|████████▎ | 4061/4860 [26:12<04:39,  2.86it/s]
# HTTP error occurred: 404 Client Error:  for url: https://api.library.tamu.edu/scholars-discovery/individual/n7b242370
#  84%|████████▎ | 4064/4860 [26:13<04:35,  2.89it/s]
# HTTP error occurred: 404 Client Error:  for url: https://api.library.tamu.edu/scholars-discovery/individual/n3706f4f0
#  87%|████████▋ | 4251/4860 [27:12<03:04,  3.30it/s]
# HTTP error occurred: 404 Client Error:  for url: https://api.library.tamu.edu/scholars-discovery/individual/n83cd1943
#  99%|█████████▊| 4789/4860 [29:52<00:20,  3.49it/s]
# HTTP error occurred: 404 Client Error:  for url: https://api.library.tamu.edu/scholars-discovery/individual/n57a931e2
# 100%|██████████| 4860/4860 [30:48<00:00,  2.63it/s]

# %% [markdown]
# It looks like there is another problem with information shifting as seen in `failed_calls[3]`. Unfortunately, I do not have the time to deal with it.
# Only 28 failed calls out of 4860; the reason is unknown.

# %%
failed_calls
# Out:
# ['https://api.library.tamu.edu/scholars-discovery/individual/n531a30c4',
#  'https://api.library.tamu.edu/scholars-discovery/individual/n6b86bf0a',
#  'https://api.library.tamu.edu/scholars-discovery/individual/nb0ba8174',
#  ' and cell wall assembly."',
#  'https://api.library.tamu.edu/scholars-discovery/individual/nb2af52ee',
#  'https://api.library.tamu.edu/scholars-discovery/individual/n6fe482a6',
#  'https://api.library.tamu.edu/scholars-discovery/individual/n14aa5202',
#  'https://api.library.tamu.edu/scholars-discovery/individual/n3d197541',
#  'https://api.library.tamu.edu/scholars-discovery/individual/n7b5179b3',
#  'https://api.library.tamu.edu/scholars-discovery/individual/n847f3873',
#  'https://api.library.tamu.edu/scholars-discovery/individual/n631e24a7',
#  'https://api.library.tamu.edu/scholars-discovery/individual/n8247cf18',
#  'https://api.library.tamu.edu/scholars-discovery/individual/n0e3856dd',
#  'https://api.library.tamu.edu/scholars-discovery/individual/ne71697c4',
#  'https://api.library.tamu.edu/scholars-discovery/individual/n3525e685',
#  'https://api.library.tamu.edu/scholars-discovery/individual/n1ab41bb2',
#  'https://api.library.tamu.edu/scholars-discovery/individual/na9655306',
#  'https://api.library.tamu.edu/scholars-discovery/individual/nf26d46a6',
#  'https://api.library.tamu.edu/scholars-discovery/individual/n981a6d1d',
#  'https://api.library.tamu.edu/scholars-discovery/individual/n87907ac0',
#  'https://api.library.tamu.edu/scholars-discovery/individual/nb2760449',
#  'https://api.library.tamu.edu/scholars-discovery/individual/ncbe3c229',
#  'https://api.library.tamu.edu/scholars-discovery/individual/n4be06dfb',
#  'https://api.library.tamu.edu/scholars-discovery/individual/n63a8f154',
#  'https://api.library.tamu.edu/scholars-discovery/individual/n7b242370',
#  'https://api.library.tamu.edu/scholars-discovery/individual/n3706f4f0',
#  'https://api.library.tamu.edu/scholars-discovery/individual/n83cd1943',
#  'https://api.library.tamu.edu/scholars-discovery/individual/n57a931e2']

# %%
# because I spelled it wrong and don't want to want 30min to correct it
successfull_calls = succesfull_calls

# %%
num_positions = {'0': 0, '1': 0, '2+': 0}
for call in successfull_calls:
    try:
        x = len(call['positions'])
        match x:
            case 0:
                num_positions['0'] += 1
            case 1:
                num_positions['1'] += 1
            case _ if x > 1:
                num_positions['2+'] += 1
            case _:
                print('Case was out of bounds.')
    except:
        num_positions['0'] += 1

print(f"Has no listed positions: {num_positions['0']}")
print(f"Has one listed position: {num_positions['1']}")
print(f"Has multiple positions: {num_positions['2+']}")
# Out:
# Has no listed positions: 57
# Has one listed position: 3935
# Has multiple positions: 840

# %%
with open('../../Data/Scholars@TAMU/my_api_calls/general_data_list.json', 'w') as outfile:
    json.dump(successfull_calls, outfile, indent=4)

# %%
succesfull_calls_by_id = {person['id']: person for person in succesfull_calls}

with open('../../Data/Scholars@TAMU/my_api_calls/general_data_dict.json', 'w') as outfile:
    json.dump(successfull_calls_by_id, outfile, indent=4)

# %% [markdown]
# ## TAMU Department Structure

# %%
api_base = 'https://api.library.tamu.edu/scholars-discovery/individual/'

tamu_info_data = get_api_dict(url=api_base + 'n5d3837d6')
tamu_info = tamu_info_data

# %%
structure_data = {
    'name': 'Texas A&M University',
    'id': 'n5d3837d6',
    'api_data': get_api_dict(api_base + 'n5d3837d6'),
    'colleges': []
    }


for college in structure_data['api_data']['hasSubOrganizations']:
    college_data = {
        'name': college['label'],
        'id': college['id'],
        'api_data': get_api_dict(api_base + college['id']),
        'departments': [],
        'research_areas': []
    }

    try:
        for department in college_data['api_data']['hasSubOrganizations']:
            department_data = {
                'name': department['label'],
                'id': department['id'],
                'api_data': get_api_dict(api_base + department['id'])
            }
            college_data['departments'].append(department_data)
    except KeyError:
        print(college_data['name'] + ' has no departments.')

    
    try:
        for research in college_data['api_data']['affiliatedResearchAreas']:
            research_data = {
                'name': research['label'],
                'id': research['id'],
                'api_data': get_api_dict(api_base + research['id'])
            }
            college_data['research_areas'].append(research_data)
    except KeyError:
        print(college_data['name'] + ' has no reseach areas.')

    structure_data['colleges'].append(college_data)
# Out:
# Office of Academic Affairs has no departments.
# Office of Academic Affairs has no reseach areas.
# Texas A&M Institute for Neuroscience has no departments.
# Texas A&M Engineering Extension Service (TEEX) has no departments.
# School of Law has no departments.
# Office of the Provost and Executive Vice President has no departments.
# Office of the President has no reseach areas.
# Texas A&M Veterinary Medical Diagnostic Laboratory has no departments.
# Albritton Center for Grand Strategy has no departments.
# College of Architecture has no reseach areas.
# Institute for Sustainable Communities has no departments.
# Institute for Sustainable Communities has no reseach areas.

# %%
tamu_structure = structure_data.copy()

del tamu_structure['api_data']
for college in tamu_structure['colleges']:
    try:
        del college['api_data']
    except KeyError:
        print(college['name'] + " has no api_data.")
    
    for department in college['departments']:
        try:
            del department['api_data']
        except KeyError:
            print(college['name'] + " has no departments.")
    for research_area in college['research_areas']:
        try:
            del research_area['api_data']
        except KeyError:
            print(college['name'] + " has no research areas.")
        

tamu_structure
# Out:
# Office of Academic Affairs has no api_data.
# Texas A&M Institute for Neuroscience has no api_data.
# Texas A&M Engineering Extension Service (TEEX) has no api_data.
# School of Law has no api_data.
# Office of the Provost and Executive Vice President has no api_data.
# Texas A&M University at Galveston has no api_data.
# Texas A&M Engineering Experiment Station (TEES) has no api_data.
# Office of the President has no api_data.
# University Libraries has no api_data.
# Texas A&M Veterinary Medical Diagnostic Laboratory has no api_data.
# College of Science has no api_data.
# Albritton Center for Grand Strategy has no api_data.
# Texas A&M AgriLife Research has no api_data.
# Bush School of Government and Public Service has no api_data.
# College of Engineering has no api_data.
# College of Geosciences has no api_data.
# Mays Business School has no api_data.
# Texas A&M University at Qatar has no api_data.
# Texas A&M AgriLIFE Extension has no api_data.
# Texas A&M Transportation Institute (TTI) has no api_data.
# College of Education and Human Development has no api_data.
# College of Architecture has no api_data.
# College of Veterinary Medicine and Biomedical Sciences has no api_data.
# Institute for Sustainable Communities has no api_data.
# Health Science Center has no api_data.
# College of Liberal Arts has no api_data.
# {'name': 'Texas A&M University',
#  'id': 'n5d3837d6',
#  'colleges': [{'name': 'Office of Academic Affairs',
#    'id': 'n78eb517b',
#    'departments': [],
#    'research_areas': []},
#   {'name': 'Texas A&M Institute for Neuroscience',
#    'id': 'n772ec370',
#    'departments': [],
#    'research_areas': [{'name': 'Medical sciences', 'id': 'nfst01014601'},
#     {'name': 'Art', 'id': 'nfst00815177'},
#     {'name': 'Psychology', 'id': 'nfst01081447'},
#     {'name': 'Electroencephalography', 'id': 'nfst00906445'},
#     {'name': 'Music', 'id': 'nfst01030269'},
#     {'name': 'Visual perception', 'id': 'nfst01168049'},
#     {'name': 'Public health', 'id': 'nfst01082238'},
#     {'name': 'Public health disparities', 'id': 'nfst01082238'},
#     {'name': 'History', 'id': 'nfst00958235'},
#     {'name': 'Neurosciences', 'id': 'nfst01036509'},
#     {'name': 'Electromyography', 'id': 'nfst00906641'},
#     {'name': 'Biomechanics', 'id': 'nfst00832558'}]},
#   {'name': 'Texas A&M Engineering Extension Service (TEEX)',
#    'id': 'n51893cda',
#    'departments': [],
#    'research_areas': [{'name': 'Future life', 'id': 'nfst00936730'},
#     {'name': 'Organizational change', 'id': 'nfst01047828'},
#     {'name': 'Occupational training', 'id': 'nfst01043313'},
#     {'name': 'Technological innovations', 'id': 'nfst01145002'},
#     {'name': 'Emergency management', 'id': 'nfst00908500'}]},
#   {'name': 'School of Law',
#    'id': 'n52ff53af',
#    'departments': [],
#    'research_areas': [{'name': 'Economics--Psychological aspects',
#      'id': 'nfst00902172'},
#     {'name': 'Research', 'id': 'nfst01095153'},
#     {'name': 'Blogs', 'id': 'nfst01429931'},
#     {'name': 'Jurisdiction', 'id': 'nfst00985026'},
#     {'name': 'Collection laws', 'id': 'nfst00867181'},
#     {'name': 'Corporations', 'id': 'nfst00879777'},
#     {'name': 'Law and art', 'id': 'nfst00993894'},
#     {'name': 'Publicity (Law)', 'id': 'nfst01083459'},
#     {'name': 'Class actions (Civil procedure)', 'id': 'nfst00863419'},
#     {'name': 'Mental health laws', 'id': 'nfst01016447'},
#     {'name': 'Experiential learning', 'id': 'nfst00918393'},
#     {'name': 'Trademarks--Law and legislation', 'id': 'nfst01153903'},
#     {'name': 'Reference services (Libraries)', 'id': 'nfst01092439'},
#     {'name': 'Digital communications--Law and legislation',
#      'id': 'nfst01767835'},
#     {'name': 'Agricultural development projects', 'id': 'nfst00800659'},
#     {'name': 'Marijuana--Law and legislation', 'id': 'nfst01009265'},
#     {'name': 'Mediation', 'id': 'nfst01013617'},
#     {'name': 'Public health laws, International', 'id': 'nfst01082374'},
#     {'name': 'Patents', 'id': 'nfst01054862'},
#     {'name': 'Freedom of religion', 'id': 'nfst00934030'},
#     {'name': 'Criminal law', 'id': 'nfst00883328'},
#     {'name': 'Dispute resolution (Law)', 'id': 'nfst00895372'},
#     {'name': 'Law and economics', 'id': 'nfst00993900'},
#     {'name': 'Uniform commercial code. Sales', 'id': 'nfst01917632'},
#     {'name': 'Business enterprises', 'id': 'nfst00842519'},
#     {'name': 'Administrative law', 'id': 'nfst00796846'},
#     {'name': 'International business enterprises--Taxation--Law and legislation',
#      'id': 'nfst00976847'},
#     {'name': 'Adoption', 'id': 'nfst00797076'},
#     {'name': 'Environmental law, International', 'id': 'nfst00913170'},
#     {'name': 'Electronic contracts', 'id': 'nfst01202151'},
#     {'name': 'Technological innovations--Finance', 'id': 'nfst01145023'},
#     {'name': 'Land use', 'id': 'nfst00991472'},
#     {'name': 'Energy policy', 'id': 'nfst00910200'},
#     {'name': 'International law', 'id': 'nfst00976984'},
#     {'name': 'Deceptive advertising--Law and legislation',
#      'id': 'nfst00888986'},
#     {'name': 'Water rights (International law)', 'id': 'nfst01172078'},
#     {'name': 'Local government--Law and legislation', 'id': 'nfst01001344'},
#     {'name': 'Refugees--Legal status, laws, etc.', 'id': 'nfst01092822'},
#     {'name': 'Administrative regulations', 'id': 'nfst01774231'},
#     {'name': 'Civil procedure (International law)', 'id': 'nfst00862616'},
#     {'name': 'Computer crimes', 'id': 'nfst00872063'},
#     {'name': 'Legal services--Technological innovations',
#      'id': 'nfst00995556'},
#     {'name': 'Texas. Court of Appeals', 'id': 'nfst00510285'},
#     {'name': 'Intellectual property (International law)',
#      'id': 'nfst00975795'},
#     {'name': 'Wills', 'id': 'nfst01175513'},
#     {'name': 'Primary health care--Government policy', 'id': 'nfst01076348'},
#     {'name': 'Legal ethics', 'id': 'nfst00995475'},
#     {'name': 'Patent laws and legislation', 'id': 'nfst01054823'},
#     {'name': 'International business enterprises--Law and legislation',
#      'id': 'nfst00976808'},
#     {'name': 'Water--Law and legislation', 'id': 'nfst01171236'},
#     {'name': 'Land use--Law and legislation', 'id': 'nfst00991514'},
#     {'name': 'Information organization', 'id': 'nfst00972595'},
#     {'name': 'Asia', 'id': 'nfst01240495'},
#     {'name': 'Law libraries', 'id': 'nfst00994020'},
#     {'name': 'Consolidation and merger of corporations', 'id': 'nfst00875660'},
#     {'name': 'Securities', 'id': 'nfst01110743'},
#     {'name': 'Freedom of speech', 'id': 'nfst00934044'},
#     {'name': 'Negotiation', 'id': 'nfst01035551'},
#     {'name': 'Arbitration (International law)', 'id': 'nfst01761738'},
#     {'name': 'Law--Political aspects', 'id': 'nfst00993795'},
#     {'name': 'Rhetoric', 'id': 'nfst01096948'},
#     {'name': 'Internship programs', 'id': 'nfst00977327'},
#     {'name': 'Constitutional history', 'id': 'nfst00875777'},
#     {'name': 'Nonprofit organizations', 'id': 'nfst01038875'},
#     {'name': 'Transfer pricing', 'id': 'nfst01154627'},
#     {'name': 'Foreign Corrupt Practices Act of 1977 (United States)',
#      'id': 'nfst01362322'},
#     {'name': 'Copyright', 'id': 'nfst00878706'},
#     {'name': 'Research--Moral and ethical aspects', 'id': 'nfst01095225'},
#     {'name': 'Law--Study and teaching (Clinical education)',
#      'id': 'nfst00993849'},
#     {'name': 'United States. Supreme Court', 'id': 'nfst00529481'},
#     {'name': 'Industrial policy', 'id': 'nfst00971433'},
#     {'name': 'Internet--Law and legislation', 'id': 'nfst00977193'},
#     {'name': 'Emigration and immigration--Economic aspects',
#      'id': 'nfst00908694'},
#     {'name': 'Law--Psychological aspects', 'id': 'nfst00993801'},
#     {'name': 'Business communication--Study and teaching',
#      'id': 'nfst00842436'},
#     {'name': 'India', 'id': 'nfst01210276'},
#     {'name': 'International law and human rights', 'id': 'nfst01894145'},
#     {'name': 'Collective bargaining', 'id': 'nfst00867190'},
#     {'name': 'Foreign trade regulation', 'id': 'nfst00931923'},
#     {'name': 'Agricultural laws and legislation', 'id': 'nfst00801020'},
#     {'name': 'Money laundering--Prevention', 'id': 'nfst01025323'},
#     {'name': 'Reasoning', 'id': 'nfst01091282'},
#     {'name': 'Land use--Planning', 'id': 'nfst00991528'},
#     {'name': 'Trademarks', 'id': 'nfst01153892'},
#     {'name': 'Legal research and writing', 'id': 'nfst01785961'},
#     {'name': 'Entrepreneurship', 'id': 'nfst00912787'},
#     {'name': 'Negotiation in business', 'id': 'nfst01035573'},
#     {'name': 'Trusts and trustees--Accounting', 'id': 'nfst01158202'},
#     {'name': 'Eminent domain', 'id': 'nfst00908749'},
#     {'name': 'Trade associations', 'id': 'nfst01153802'},
#     {'name': 'Professional ethics', 'id': 'nfst01078521'},
#     {'name': 'Climatic change', 'id': 'nfst00864229'},
#     {'name': 'Climatic changes, Climate Dynamics and Prediction',
#      'id': 'nfst00864229'},
#     {'name': 'Climatic changes', 'id': 'nfst00864229'},
#     {'name': 'Commercial law', 'id': 'nfst00869502'},
#     {'name': 'Technology--Law and legislation', 'id': 'nfst01145151'},
#     {'name': 'Privacy, Right of', 'id': 'nfst01077444'},
#     {'name': 'Lawyers--Discipline', 'id': 'nfst00994365'},
#     {'name': 'Natural language processing', 'id': 'nfst01397704'},
#     {'name': 'Accounting', 'id': 'nfst00795379'},
#     {'name': 'Information theory', 'id': 'nfst00973149'},
#     {'name': 'Fashion merchandising--Law and legislation',
#      'id': 'nfst00921646'},
#     {'name': 'Habeas corpus', 'id': 'nfst00950021'},
#     {'name': 'Plea bargaining', 'id': 'nfst01067062'},
#     {'name': 'Science and law', 'id': 'nfst01108529'},
#     {'name': 'Complex litigation', 'id': 'nfst00871591'},
#     {'name': 'Natural resources--Law and legislation', 'id': 'nfst01034431'},
#     {'name': 'Finance, Personal', 'id': 'nfst00924449'},
#     {'name': 'Privacy Protection Act of 1980 (United States)',
#      'id': 'nfst01368735'},
#     {'name': 'Discrimination in housing', 'id': 'nfst00895081'},
#     {'name': 'Human Resource Development and African Americans',
#      'id': 'nfst00902499'},
#     {'name': 'Education', 'id': 'nfst00902499'},
#     {'name': 'Emigration and immigration law', 'id': 'nfst00908736'},
#     {'name': 'Trusts and trustees', 'id': 'nfst01158201'},
#     {'name': 'Library science', 'id': 'nfst00997916'},
#     {'name': 'Malpractice insurance', 'id': 'nfst01715880'},
#     {'name': 'Criminal investigation', 'id': 'nfst00883201'},
#     {'name': 'Malpractice', 'id': 'nfst01006824'},
#     {'name': 'Capital punishment', 'id': 'nfst00846392'},
#     {'name': 'International business enterprises', 'id': 'nfst00976774'},
#     {'name': 'Refugees', 'id': 'nfst01092797'},
#     {'name': 'Renewable energy sources--Law and legislation',
#      'id': 'nfst01094586'},
#     {'name': 'International trade', 'id': 'nfst00977128'},
#     {'name': 'Amusements--Law and legislation', 'id': 'nfst00808111'},
#     {'name': 'Electronic funds transfers', 'id': 'nfst00907204'},
#     {'name': 'Federal Rules of Evidence (United States)',
#      'id': 'nfst01364687'},
#     {'name': 'Bankruptcy', 'id': 'nfst00826826'},
#     {'name': 'Environmental law', 'id': 'nfst00913122'},
#     {'name': 'Comparative law', 'id': 'nfst00871350'},
#     {'name': 'Freedom of the press', 'id': 'nfst00934063'},
#     {'name': 'Fair Debt Collection Practices Act (United States)',
#      'id': 'nfst01372798'},
#     {'name': 'Arbitration and award', 'id': 'nfst00812768'},
#     {'name': 'Domestic relations', 'id': 'nfst00896646'},
#     {'name': 'Labor laws and legislation', 'id': 'nfst00989967'},
#     {'name': 'Land tenure', 'id': 'nfst00991362'},
#     {'name': 'Pharmaceutical biotechnology--Law and legislation',
#      'id': 'nfst01060107'},
#     {'name': 'Constitutional law', 'id': 'nfst00875797'},
#     {'name': 'Rule of law', 'id': 'nfst01101218'},
#     {'name': 'Civil procedure', 'id': 'nfst00862585'},
#     {'name': 'European Union', 'id': 'nfst00916630'},
#     {'name': 'Bioethics', 'id': 'nfst00832038'},
#     {'name': 'Petroleum law and legislation', 'id': 'nfst01059663'},
#     {'name': 'Property', 'id': 'nfst01079116'},
#     {'name': 'Work environment', 'id': 'nfst01180270'},
#     {'name': 'Private equity', 'id': 'nfst01077481'},
#     {'name': 'Intellectual property', 'id': 'nfst00975774'},
#     {'name': 'Antitrust law', 'id': 'nfst00810849'},
#     {'name': 'Library outreach programs', 'id': 'nfst00997869'},
#     {'name': 'Law--Study and teaching', 'id': 'nfst00993829'},
#     {'name': 'Corruption', 'id': 'nfst01352550'},
#     {'name': 'Business transactions', 'id': 'nfst01777968'},
#     {'name': 'Uniform commercial code', 'id': 'nfst01357346'},
#     {'name': 'International agencies', 'id': 'nfst00976708'},
#     {'name': 'Consumer behavior--Public opinion', 'id': 'nfst00876248'},
#     {'name': 'Sentences (Criminal procedure)', 'id': 'nfst01112638'},
#     {'name': 'Estate planning', 'id': 'nfst00915490'},
#     {'name': 'Employee rights', 'id': 'nfst00909055'},
#     {'name': 'Uniform commercial code. Secured transactions',
#      'id': 'nfst01380622'},
#     {'name': 'Law reform', 'id': 'nfst00994081'},
#     {'name': 'Contracts', 'id': 'nfst00876969'},
#     {'name': 'Technology--Library resources', 'id': 'nfst01145154'},
#     {'name': 'Corporation law', 'id': 'nfst00879728'},
#     {'name': 'Community development, Urban--Law and legislation',
#      'id': 'nfst00870893'},
#     {'name': 'Procedure (Law)', 'id': 'nfst01077984'},
#     {'name': 'Criminal procedure', 'id': 'nfst00883421'},
#     {'name': 'Computer security', 'id': 'nfst00872484'},
#     {'name': 'Racketeer Influenced and Corrupt Organizations Act (United States)',
#      'id': 'nfst01368266'},
#     {'name': 'Commercial policy', 'id': 'nfst00869569'},
#     {'name': 'Communication in law', 'id': 'nfst00870162'},
#     {'name': 'Trade secrets', 'id': 'nfst01153869'},
#     {'name': 'Compromise (Law)', 'id': 'nfst00871915'},
#     {'name': 'Texas. Legislature', 'id': 'nfst00533882'},
#     {'name': 'Civil law', 'id': 'nfst00862544'},
#     {'name': 'Petroleum industry and trade--International cooperation',
#      'id': 'nfst01059609'},
#     {'name': 'Sex discrimination', 'id': 'nfst01114365'},
#     {'name': 'Border 2012: U.S.-Mexico Environmental Program',
#      'id': 'nfst01675270'},
#     {'name': 'Social choice', 'id': 'nfst01122336'},
#     {'name': 'Taxation--International cooperation', 'id': 'nfst01143920'},
#     {'name': 'Real property', 'id': 'nfst01091096'},
#     {'name': 'Federal aid to law enforcement agencies', 'id': 'nfst00922223'},
#     {'name': 'Evidence (Law)', 'id': 'nfst00917186'},
#     {'name': 'Evidence, Expert', 'id': 'nfst00917231'},
#     {'name': 'Journalism', 'id': 'nfst00984032'},
#     {'name': 'Law--Study and teaching (Internship)', 'id': 'nfst00993858'},
#     {'name': 'Consumer protection', 'id': 'nfst00876358'},
#     {'name': 'Legal research', 'id': 'nfst00995522'},
#     {'name': 'Discrimination in employment', 'id': 'nfst00895050'}]},
#   {'name': 'Office of the Provost and Executive Vice President',
#    'id': 'n76004c6f',
#    'departments': [],
#    'research_areas': [{'name': 'Computer software', 'id': 'nfst00872527'}]},
#   {'name': 'Texas A&M University at Galveston',
#    'id': 'nc712f734',
#    'departments': [{'name': 'Ocean Engineering', 'id': 'n779f573f'},
#     {'name': 'Marine Engineering Technology', 'id': 'n4ff8d491'},
#     {'name': 'Foundational Sciences', 'id': 'ne52fe435'},
#     {'name': 'Maritime Transportation', 'id': 'n5f4198f8'},
#     {'name': 'Liberal Studies', 'id': 'n1807d65b'},
#     {'name': 'Marine Biology', 'id': 'na4fc1057'},
#     {'name': 'Maritime Administration', 'id': 'na979d68d'},
#     {'name': 'Marine Sciences', 'id': 'n514305a0'}],
#    'research_areas': [{'name': 'Plant physiology', 'id': 'nfst01065616'},
#     {'name': 'Phytoplankton--Ecophysiology', 'id': 'nfst01063313'},
#     {'name': 'Marine ecology', 'id': 'nfst01009513'},
#     {'name': 'Biochemistry', 'id': 'nfst00831961'},
#     {'name': 'Molecular biology', 'id': 'nfst01024734'},
#     {'name': 'Biophysics', 'id': 'nfst00832656'},
#     {'name': 'Evolution', 'id': 'nfst00917265'},
#     {'name': 'Photosynthesis', 'id': 'nfst01062108'}]},
#   {'name': 'Texas A&M Engineering Experiment Station (TEES)',
#    'id': 'n952c84ff',
#    'departments': [{'name': 'Center for Intelligent Multifunctional Materials and Structures',
#      'id': 'n2702d149'},
#     {'name': 'Nuclear Security Science and Policy Institute',
#      'id': 'nd388fa5c'},
#     {'name': 'Cybersecurity Center', 'id': 'n956be2b1'},
#     {'name': 'Center for Large-scale Scientific Simulations',
#      'id': 'n9744619d'},
#     {'name': 'TEES Regional Divisions', 'id': 'n616c5db9'},
#     {'name': 'Nuclear Science Center', 'id': 'n6768a267'},
#     {'name': 'The Turbomachinery Laboratory', 'id': 'ndae65ad8'},
#     {'name': 'Nuclear Power Institute', 'id': 'ncc6cca7f'},
#     {'name': 'National Center for Therapeutics Manufacturing',
#      'id': 'ncfe61f1d'},
#     {'name': 'National Corrosion and Materials Reliability Center',
#      'id': 'nd77d9c1a'},
#     {'name': 'Process Engineering R&D Center', 'id': 'n064ee5db'},
#     {'name': 'Energy Institute', 'id': 'nec4b9742'},
#     {'name': 'Center for Remote Health Technologies and Systems',
#      'id': 'ncfac0380'},
#     {'name': 'Gas and Fuels Research Center', 'id': 'n357bcb25'},
#     {'name': 'Energy Systems Laboratory', 'id': 'nb07b8990'},
#     {'name': 'Institute for Engineering Education and Innovation',
#      'id': 'n3c3ecaa1'},
#     {'name': 'Polymer Technology Center', 'id': 'n7e095ec2'}],
#    'research_areas': [{'name': 'Information storage and retrieval systems',
#      'id': 'nfst00972781'},
#     {'name': 'Tensegrity (Engineering)', 'id': 'nfst01910252'},
#     {'name': 'Computer vision', 'id': 'nfst00872687'},
#     {'name': 'Control theory', 'id': 'nfst00877085'},
#     {'name': 'Stochastic analysis', 'id': 'nfst01133499'},
#     {'name': 'Uncertainty', 'id': 'nfst01160832'},
#     {'name': 'Astrodynamics', 'id': 'nfst00819382'},
#     {'name': 'Structural dynamics', 'id': 'nfst01135648'},
#     {'name': 'Reliability', 'id': 'nfst01093641'},
#     {'name': 'Risk assessment', 'id': 'nfst01098146'},
#     {'name': 'Computer networks', 'id': 'nfst00872297'},
#     {'name': 'Dynamics', 'id': 'nfst00900295'},
#     {'name': 'Multiscale modeling', 'id': 'nfst01763130'},
#     {'name': 'Estimation theory', 'id': 'nfst00915531'},
#     {'name': 'Computer architecture', 'id': 'nfst00872026'},
#     {'name': 'Mechanics--computational mechanics', 'id': 'nfst01400995'},
#     {'name': 'System identification', 'id': 'nfst01141418'}]},
#   {'name': 'Office of the President',
#    'id': 'n41fc08c1',
#    'departments': [{'name': 'Division of Research', 'id': 'ne93ffa87'}],
#    'research_areas': []},
#   {'name': 'University Libraries',
#    'id': 'nb7f16f5c',
#    'departments': [{'name': 'Center for Systematic Reviews and Research Syntheses',
#      'id': 'n9cee9580'}],
#    'research_areas': [{'name': 'Technical services (Libraries)',
#      'id': 'nfst01144959'},
#     {'name': 'Linked data', 'id': 'nfst01896555'},
#     {'name': 'Open access', 'id': 'nfst01373866'},
#     {'name': 'Academic libraries--Evaluation', 'id': 'nfst00795036'},
#     {'name': 'Agriculture--Library resources', 'id': 'nfst00801563'},
#     {'name': 'Medical informatics', 'id': 'nfst01014175'},
#     {'name': 'Reference services (Libraries)', 'id': 'nfst01092439'},
#     {'name': 'Race relations', 'id': 'nfst01086509'},
#     {'name': 'Text data mining', 'id': 'nfst02008831'},
#     {'name': 'Public services (Libraries)', 'id': 'nfst01083042'},
#     {'name': 'Science--Study and teaching', 'id': 'nfst01108387'},
#     {'name': 'Library cooperation', 'id': 'nfst00997693'},
#     {'name': 'Literature', 'id': 'nfst00999953'},
#     {'name': 'Information visualization', 'id': 'nfst00973185'},
#     {'name': 'Information resources management', 'id': 'nfst00972603'},
#     {'name': 'Library orientation', 'id': 'nfst00997831'},
#     {'name': 'Data management', 'id': 'nfst00888037'},
#     {'name': 'Database management', 'id': 'nfst00888037'},
#     {'name': 'Electronic books', 'id': 'nfst00906854'},
#     {'name': 'Engineering--Education', 'id': 'nfst00910345'},
#     {'name': 'Humanities', 'id': 'nfst00963588'},
#     {'name': 'Social sciences--Research', 'id': 'nfst01122944'},
#     {'name': 'Fantasy fiction', 'id': 'nfst01726607'},
#     {'name': 'Archives', 'id': 'nfst00814030'},
#     {'name': 'Subject cataloging', 'id': 'nfst01136450'},
#     {'name': 'Public health', 'id': 'nfst01082238'},
#     {'name': 'Public health disparities', 'id': 'nfst01082238'},
#     {'name': 'Imaginary places', 'id': 'nfst00967571'},
#     {'name': 'Library materials--Digitization', 'id': 'nfst00997814'},
#     {'name': 'Libraries', 'id': 'nfst00997341'},
#     {'name': 'Science fiction', 'id': 'nfst01108566'},
#     {'name': 'Organizational change', 'id': 'nfst01047828'},
#     {'name': 'Authority files (Information retrieval)', 'id': 'nfst00821683'},
#     {'name': 'Information science', 'id': 'nfst00972640'},
#     {'name': 'Financial literacy', 'id': 'nfst01743054'},
#     {'name': 'Rhetoric', 'id': 'nfst01096948'},
#     {'name': 'Soils--Quality', 'id': 'nfst01124797'},
#     {'name': 'Sexual minorities', 'id': 'nfst01202158'},
#     {'name': 'Diversity in the workplace', 'id': 'nfst00895719'},
#     {'name': 'Learning and scholarship', 'id': 'nfst00994857'},
#     {'name': 'Semantic Web', 'id': 'nfst01112076'},
#     {'name': 'Quantitative research', 'id': 'nfst01742283'},
#     {'name': 'Digital preservation', 'id': 'nfst00893721'},
#     {'name': 'Cartography', 'id': 'nfst00848025'},
#     {'name': 'Online identities', 'id': 'nfst01740515'},
#     {'name': 'Comic books, strips, etc.', 'id': 'nfst00869145'},
#     {'name': 'Evidence-based medicine', 'id': 'nfst00917247'},
#     {'name': 'Social sciences--Network analysis', 'id': 'nfst01122938'},
#     {'name': 'Mixed methods research', 'id': 'nfst01749921'},
#     {'name': 'Diversity, Gender and Cultural', 'id': 'nfst01715991'},
#     {'name': 'Cultural pluralism', 'id': 'nfst01715991'},
#     {'name': 'Academic-industrial collaboration', 'id': 'nfst00795112'},
#     {'name': 'Business--Research', 'id': 'nfst00842371'},
#     {'name': 'Geochemistry', 'id': 'nfst00940343'},
#     {'name': 'Information literacy', 'id': 'nfst00972560'},
#     {'name': 'Systematic reviews (Medical research)', 'id': 'nfst01141436'},
#     {'name': 'Cultural competence', 'id': 'nfst01748449'},
#     {'name': 'Archival materials--Digitization', 'id': 'nfst00814004'},
#     {'name': 'Research--Management', 'id': 'nfst01095208'},
#     {'name': 'Map collections', 'id': 'nfst01008662'},
#     {'name': 'Popular culture', 'id': 'nfst01071344'},
#     {'name': 'Academic libraries', 'id': 'nfst00794997'},
#     {'name': 'Business libraries', 'id': 'nfst00842744'},
#     {'name': 'Computer games', 'id': 'nfst00872108'},
#     {'name': 'Information science--Research', 'id': 'nfst00972662'},
#     {'name': 'Bibliometrics', 'id': 'nfst00831408'},
#     {'name': 'Digital libraries', 'id': 'nfst00893704'},
#     {'name': 'Humanities--Digital libraries', 'id': 'nfst00963602'},
#     {'name': 'American literature', 'id': 'nfst00807113'},
#     {'name': 'Entrepreneurship', 'id': 'nfst00912787'},
#     {'name': 'Artificial intelligence', 'id': 'nfst00817247'},
#     {'name': 'Computer science', 'id': 'nfst00872451'},
#     {'name': 'Library administration', 'id': 'nfst00997606'},
#     {'name': 'Electronic information resources', 'id': 'nfst00907295'},
#     {'name': 'Veterinary medicine', 'id': 'nfst01165977'},
#     {'name': 'Editing', 'id': 'nfst00902451'},
#     {'name': 'Personnel management', 'id': 'nfst01058797'},
#     {'name': 'Collection development (Libraries)', 'id': 'nfst00867172'},
#     {'name': 'Library science', 'id': 'nfst00997916'},
#     {'name': 'Institutional repositories', 'id': 'nfst01740486'},
#     {'name': 'Communication in learning and scholarship',
#      'id': 'nfst00870164'},
#     {'name': 'Social sciences--Research--Data processing',
#      'id': 'nfst01122948'},
#     {'name': 'Medical librarianship', 'id': 'nfst01202127'},
#     {'name': 'Environmental education', 'id': 'nfst00912902'},
#     {'name': 'Writing', 'id': 'nfst01181638'},
#     {'name': 'Veterans', 'id': 'nfst01165710'},
#     {'name': 'Oral history--Archival resources', 'id': 'nfst01047056'},
#     {'name': 'Qualitative research', 'id': 'nfst01084940'},
#     {'name': 'Oral history--Methodology', 'id': 'nfst01047060'},
#     {'name': 'Academic libraries--Acquisitions', 'id': 'nfst00794999'},
#     {'name': 'Digital humanities', 'id': 'nfst00963599'},
#     {'name': 'Metadata', 'id': 'nfst01017519'},
#     {'name': 'Critical pedagogy', 'id': 'nfst00883676'},
#     {'name': 'Educational technology--Research', 'id': 'nfst00903644'},
#     {'name': 'Bibliography', 'id': 'nfst01423717'},
#     {'name': 'Library circulation and loans', 'id': 'nfst00997679'},
#     {'name': 'Creative writing', 'id': 'nfst00882489'},
#     {'name': 'Library outreach programs', 'id': 'nfst00997869'},
#     {'name': 'Cultural property', 'id': 'nfst00885014'},
#     {'name': 'Public health--Information services', 'id': 'nfst01082271'},
#     {'name': 'Ontologies (Information retrieval)', 'id': 'nfst01739863'},
#     {'name': 'Education, Higher', 'id': 'nfst00903005'},
#     {'name': 'Academic libraries--Reference services', 'id': 'nfst00795059'},
#     {'name': 'Emergency management', 'id': 'nfst00908500'},
#     {'name': 'Libraries--Special collections--Maps', 'id': 'nfst01766805'},
#     {'name': 'Acquisitions (Libraries)', 'id': 'nfst00796015'},
#     {'name': 'Statistics', 'id': 'nfst01132103'},
#     {'name': 'Games', 'id': 'nfst00937529'}]},
#   {'name': 'Texas A&M Veterinary Medical Diagnostic Laboratory',
#    'id': 'nbc6e1b2b',
#    'departments': [],
#    'research_areas': [{'name': 'Drug resistance in microorganisms',
#      'id': 'nfst00898704'},
#     {'name': 'Diagnosis, Laboratory', 'id': 'nfst00892307'},
#     {'name': 'Foodborne diseases--Microbiology', 'id': 'nfst00931255'}]},
#   {'name': 'College of Science',
#    'id': 'n7267255d',
#    'departments': [{'name': 'Mathematics', 'id': 'n73bc0d79'},
#     {'name': 'Physics and Astronomy', 'id': 'n68f225f4'},
#     {'name': 'Center for Statistical Bioinformatics', 'id': 'nc17d808a'},
#     {'name': 'Biology', 'id': 'ne1d4c4ac'},
#     {'name': 'Statistics', 'id': 'nd72a586b'},
#     {'name': 'Chemistry', 'id': 'nce401957'},
#     {'name': 'Center for Electrochemical Systems and Hydrogen Research',
#      'id': 'nee70595e'}],
#    'research_areas': [{'name': 'Control theory', 'id': 'nfst00877085'},
#     {'name': 'Applied mathematics', 'id': 'nfst01400410'},
#     {'name': 'Differential equations, Partial', 'id': 'nfst00893484'},
#     {'name': 'Differential equations--Numerical solutions',
#      'id': 'nfst00893451'},
#     {'name': 'Navier-Stokes equations', 'id': 'nfst01035071'},
#     {'name': 'Attractors (Mathematics)', 'id': 'nfst00820911'},
#     {'name': 'Turbulence--Mathematical models', 'id': 'nfst01159216'}]},
#   {'name': 'Albritton Center for Grand Strategy',
#    'id': 'n1ab1b7d7',
#    'departments': [],
#    'research_areas': [{'name': 'Security, International',
#      'id': 'nfst01110895'},
#     {'name': 'Military history, Modern', 'id': 'nfst01021239'},
#     {'name': 'Arabian Peninsula', 'id': 'nfst01240131'},
#     {'name': 'Petroleum', 'id': 'nfst01059260'},
#     {'name': 'International relations', 'id': 'nfst00977053'},
#     {'name': 'Middle East--Persian Gulf Region', 'id': 'nfst01244349'},
#     {'name': 'Military history', 'id': 'nfst01411630'},
#     {'name': 'Middle East', 'id': 'nfst01241586'}]},
#   {'name': 'Texas A&M AgriLife Research',
#    'id': 'nc8b9f721',
#    'departments': [{'name': 'Dallas Research and Extension Center',
#      'id': 'n869daec6'},
#     {'name': 'Temple Research and Extension Center', 'id': 'n1bd509c0'},
#     {'name': 'Corpus Christi Research and Extension Center',
#      'id': 'n92e9ab11'},
#     {'name': 'El Paso Research and Extension Center', 'id': 'nddc73641'},
#     {'name': 'Stephenville Research and Extension Center', 'id': 'n2b12a3f3'},
#     {'name': 'Weslaco Research and Extension Center', 'id': 'n8f5fab75'},
#     {'name': 'Overton Research and Extension Center', 'id': 'n92a3b78c'},
#     {'name': 'Vernon Research and Extension Center', 'id': 'nba884f19'},
#     {'name': 'Beaumont Research and Extension Center', 'id': 'n0ca7962d'},
#     {'name': 'Amarillo Research and Extension Center', 'id': 'ncecc80b2'},
#     {'name': 'Lubbock Research and Extension Center', 'id': 'ncc736b32'},
#     {'name': 'Uvalde Research and Extension Center', 'id': 'ncbb3f3d9'},
#     {'name': 'San Angelo Research and Extension Center', 'id': 'n2b0a4f66'}],
#    'research_areas': [{'name': 'Reproduction', 'id': 'nfst01094973'},
#     {'name': 'Intestine, Small', 'id': 'nfst00977660'},
#     {'name': 'Soil moisture', 'id': 'nfst01124492'},
#     {'name': 'Turfgrasses', 'id': 'nfst01159262'},
#     {'name': 'Cropping systems', 'id': 'nfst00883953'},
#     {'name': 'Fishes', 'id': 'nfst00926361'},
#     {'name': 'Biochemistry', 'id': 'nfst00831961'},
#     {'name': 'High throughput field phenotyping', 'id': 'nfst00868966'},
#     {'name': 'Sheep', 'id': 'nfst01115460'},
#     {'name': 'Immunology', 'id': 'nfst00968006'},
#     {'name': 'Precision agriculture', 'id': 'nfst01074972'},
#     {'name': 'Precision farming', 'id': 'nfst01074972'},
#     {'name': 'Dairy cattle', 'id': 'nfst00886806'},
#     {'name': 'Cattle', 'id': 'nfst00849460'},
#     {'name': 'Bioinformatics', 'id': 'nfst00832181'},
#     {'name': 'Amino acids', 'id': 'nfst00807622'},
#     {'name': 'Animals--Growth', 'id': 'nfst00809502'},
#     {'name': 'Cotton', 'id': 'nfst00880858'},
#     {'name': 'Molecular genetics', 'id': 'nfst01024797'},
#     {'name': 'Obesity', 'id': 'nfst01042738'},
#     {'name': 'MicroRNA', 'id': 'nfst01940234'},
#     {'name': 'Genomics', 'id': 'nfst00940228'},
#     {'name': 'Plants--Evolution', 'id': 'nfst01066028'},
#     {'name': 'Environmental', 'id': 'nfst00901476'},
#     {'name': 'Ecology', 'id': 'nfst00901476'},
#     {'name': 'Environment', 'id': 'nfst00901476'},
#     {'name': 'Poultry', 'id': 'nfst01073919'},
#     {'name': 'Swine', 'id': 'nfst01140419'},
#     {'name': 'Cell division', 'id': 'nfst00850186'},
#     {'name': 'Proteins in human nutrition', 'id': 'nfst01079770'},
#     {'name': 'Cardiovascular system--Diseases', 'id': 'nfst00847181'},
#     {'name': 'Beef cattle--Cow-calf system--Research', 'id': 'nfst00829631'},
#     {'name': 'Crop and water relations', 'id': 'nfst00884100'},
#     {'name': 'Molecular biology', 'id': 'nfst01024734'},
#     {'name': 'Drought-tolerant plants', 'id': 'nfst00898447'},
#     {'name': 'Plant molecular biology', 'id': 'nfst01065557'},
#     {'name': 'Shrimps', 'id': 'nfst01117815'},
#     {'name': 'Machine learning', 'id': 'nfst01004795'},
#     {'name': 'DNA microarrays', 'id': 'nfst00886592'},
#     {'name': 'RNA', 'id': 'nfst01086244'},
#     {'name': 'UAV remote sensing', 'id': 'nfst01710116'},
#     {'name': 'Musculoskeletal system', 'id': 'nfst01030016'},
#     {'name': 'Heart', 'id': 'nfst00953493'},
#     {'name': 'Geographic information systems', 'id': 'nfst00940423'},
#     {'name': 'Diabetes', 'id': 'nfst00892147'},
#     {'name': 'Agriculture', 'id': 'nfst00801355'},
#     {'name': 'Genotype-environment interaction', 'id': 'nfst00940233'},
#     {'name': 'DNA replication', 'id': 'nfst00886601'},
#     {'name': 'Bacterial genetics', 'id': 'nfst00825221'},
#     {'name': 'Kidneys', 'id': 'nfst00987372'},
#     {'name': 'Metabolism', 'id': 'nfst01017473'},
#     {'name': 'Mice', 'id': 'nfst01019337'},
#     {'name': 'Bacillus (Bacteria)', 'id': 'nfst00825051'},
#     {'name': 'Beef cattle--Reproduction', 'id': 'nfst00829686'},
#     {'name': 'Liver', 'id': 'nfst01000617'},
#     {'name': 'Lactation', 'id': 'nfst00990595'},
#     {'name': 'Physiology', 'id': 'nfst01063177'},
#     {'name': 'Plant genomes', 'id': 'nfst01065465'},
#     {'name': 'Water efficiency', 'id': 'nfst01171716'},
#     {'name': 'Animal nutrition', 'id': 'nfst00809306'},
#     {'name': 'Plant breeding--Research', 'id': 'nfst01065295'},
#     {'name': 'Plant molecular genetics', 'id': 'nfst01065562'},
#     {'name': 'Brain', 'id': 'nfst00837570'},
#     {'name': 'Genetics', 'id': 'nfst00940117'},
#     {'name': 'Crops--Physiology', 'id': 'nfst00884045'},
#     {'name': 'Rats', 'id': 'nfst01090300'},
#     {'name': 'Field crops--Physiology', 'id': 'nfst00923848'},
#     {'name': 'Beef cattle', 'id': 'nfst00829613'},
#     {'name': 'Plant physiology', 'id': 'nfst01065616'},
#     {'name': 'Microbial metabolism', 'id': 'nfst01019522'},
#     {'name': 'Fatty liver', 'id': 'nfst00921974'}]},
#   {'name': 'Bush School of Government and Public Service',
#    'id': 'n3c6ba885',
#    'departments': [{'name': 'Scowcroft Institute of International Affairs',
#      'id': 'nfb7d949b'},
#     {'name': 'International Affairs', 'id': 'n880fc637'},
#     {'name': 'Center for Nonprofits and Philanthropy', 'id': 'n922283e8'},
#     {'name': 'Public Service and Administration', 'id': 'nfb937de2'},
#     {'name': 'Albritton Center for Grand Strategy', 'id': 'n1ab1b7d7'}],
#    'research_areas': [{'name': 'Special districts', 'id': 'nfst01128830'},
#     {'name': 'Mobile communication systems in education',
#      'id': 'nfst01736419'},
#     {'name': 'Debts, Public--Management', 'id': 'nfst00888871'},
#     {'name': 'Cities and towns', 'id': 'nfst00861748'},
#     {'name': 'Instructional systems--Design', 'id': 'nfst00974357'},
#     {'name': 'Municipal bonds', 'id': 'nfst01029183'},
#     {'name': 'Educational technology', 'id': 'nfst00903623'},
#     {'name': 'Capital budget', 'id': 'nfst00846290'},
#     {'name': 'Public administration', 'id': 'nfst01081976'},
#     {'name': 'Local government', 'id': 'nfst01001300'},
#     {'name': 'Public utilities--Government policy', 'id': 'nfst01083173'},
#     {'name': 'Finance, Public', 'id': 'nfst00924477'},
#     {'name': 'Government spending policy', 'id': 'nfst00945615'},
#     {'name': 'Infrastructure (Economics)--Finance', 'id': 'nfst00973283'},
#     {'name': 'Urban policy', 'id': 'nfst01162489'},
#     {'name': 'Infrastructure (Economics)--Government policy',
#      'id': 'nfst00973286'}]},
#   {'name': 'College of Engineering',
#    'id': 'n8627320c',
#    'departments': [{'name': 'Civil Engineering', 'id': 'n4f6c1991'},
#     {'name': 'Engineering Education Research Taskforce', 'id': 'nffe5ffe1'},
#     {'name': 'Engineering Technology and Industrial Distribution',
#      'id': 'n2c8a5f2c'},
#     {'name': 'Ocean Engineering', 'id': 'n12a7d238'},
#     {'name': 'Nuclear Engineering', 'id': 'n5ad795f8'},
#     {'name': 'Electrical and Computer Engineering', 'id': 'n2478ed4a'},
#     {'name': 'Industrial and Systems Engineering', 'id': 'n158a9114'},
#     {'name': 'Computer Science and Engineering', 'id': 'n3b8431fc'},
#     {'name': 'Petroleum Engineering', 'id': 'nc9f29292'},
#     {'name': 'Biological and Agricultural Engineering', 'id': 'ncd2c1725'},
#     {'name': 'Mechanical Engineering', 'id': 'n1b7311c9'},
#     {'name': 'Aerospace Engineering', 'id': 'nc59ef216'},
#     {'name': 'Chemical Engineering', 'id': 'nf2f6fdfa'},
#     {'name': 'Biomedical Engineering', 'id': 'ned12cdd9'},
#     {'name': 'Materials Science and Engineering', 'id': 'n09ed9c6e'},
#     {'name': 'Aggie STEM', 'id': 'nb89b5d43'}],
#    'research_areas': [{'name': 'Information storage and retrieval systems',
#      'id': 'nfst00972781'},
#     {'name': 'Building', 'id': 'nfst00840551'},
#     {'name': 'Problem-based learning', 'id': 'nfst01077955'},
#     {'name': 'Climatic change', 'id': 'nfst00864229'},
#     {'name': 'Climatic changes, Climate Dynamics and Prediction',
#      'id': 'nfst00864229'},
#     {'name': 'Climatic changes', 'id': 'nfst00864229'},
#     {'name': 'Fractional calculus', 'id': 'nfst00933515'},
#     {'name': 'Diversity in higher education', 'id': 'nfst01780787'},
#     {'name': 'Cloud computing', 'id': 'nfst01745899'},
#     {'name': 'Civil procedure', 'id': 'nfst00862585'},
#     {'name': 'Robotics', 'id': 'nfst01098997'},
#     {'name': 'Fuzzy logic-based control', 'id': 'nfst00936807'},
#     {'name': 'Sliding mode control', 'id': 'nfst01120910'},
#     {'name': 'Engineering--Study and teaching', 'id': 'nfst00910417'},
#     {'name': 'Project method in teaching', 'id': 'nfst01078807'},
#     {'name': 'Project-based Learning', 'id': 'nfst01078807'},
#     {'name': 'Intellectual property', 'id': 'nfst00975774'},
#     {'name': 'Mathematical optimization', 'id': 'nfst01012099'},
#     {'name': 'Plasma (Ionized gases)', 'id': 'nfst01066262'},
#     {'name': 'Autonomous robots', 'id': 'nfst00824159'},
#     {'name': 'Prediction of scholastic success', 'id': 'nfst01075030'},
#     {'name': 'Computational science and engineering', 'id': 'nfst01779319'},
#     {'name': 'Computer architecture', 'id': 'nfst00872026'},
#     {'name': 'Law and economics', 'id': 'nfst00993900'},
#     {'name': 'National Society of Professional Engineers. Task Force on Political Involvement in Awarding Engineering Contracts',
#      'id': 'nfst00517469'},
#     {'name': 'Web-based instruction', 'id': 'nfst01173272'},
#     {'name': 'Administrative law', 'id': 'nfst00796846'},
#     {'name': 'Nanostructured materials', 'id': 'nfst01032630'},
#     {'name': 'Operating systems (Computers)', 'id': 'nfst01046280'},
#     {'name': 'Chemical processes--Simulation methods', 'id': 'nfst00853168'},
#     {'name': 'high-end computing', 'id': 'nfst00906987'},
#     {'name': 'Engineering--Education', 'id': 'nfst00910345'},
#     {'name': 'Corporation law', 'id': 'nfst00879728'},
#     {'name': 'Energy policy', 'id': 'nfst00910200'},
#     {'name': 'Teaching teams', 'id': 'nfst01144645'},
#     {'name': 'Natural gas', 'id': 'nfst01034049'},
#     {'name': 'Engineers--Professional ethics', 'id': 'nfst00910668'},
#     {'name': 'Biomass energy', 'id': 'nfst00832532'},
#     {'name': 'Chemical processes', 'id': 'nfst00853156'},
#     {'name': 'Chemical processes--Computer simulation', 'id': 'nfst00853160'},
#     {'name': 'Intelligent tutoring systems', 'id': 'nfst00975916'},
#     {'name': 'Lyapunov stability theory', 'id': 'nfst01004173'},
#     {'name': 'Career development', 'id': 'nfst00847280'},
#     {'name': 'Active learning', 'id': 'nfst00796275'},
#     {'name': 'Computational fluid dynamics', 'id': 'nfst01745072'},
#     {'name': 'Computer networks', 'id': 'nfst00872297'},
#     {'name': 'Environmental law', 'id': 'nfst00913122'},
#     {'name': 'Project management--Evaluation', 'id': 'nfst01078802'},
#     {'name': 'Patent laws and legislation', 'id': 'nfst01054823'}]},
#   {'name': 'College of Geosciences',
#    'id': 'nfeec0e89',
#    'departments': [{'name': 'Atmospheric Sciences', 'id': 'nbbb26cf0'},
#     {'name': 'Geology and Geophysics', 'id': 'nc82ffe80'},
#     {'name': 'Oceanography', 'id': 'n472b8901'},
#     {'name': 'Center for Tectonophysics', 'id': 'na9825e5f'},
#     {'name': 'Geography', 'id': 'nfcd041ac'}],
#    'research_areas': [{'name': 'Oceanography', 'id': 'nfst01043671'},
#     {'name': 'Ocean temperature', 'id': 'nfst01043561'},
#     {'name': 'Ocean currents', 'id': 'nfst01043489'},
#     {'name': 'Ocean salinity', 'id': 'nfst02010599'},
#     {'name': 'Gulf of Mexico', 'id': 'nfst01239980'},
#     {'name': 'Engineering', 'id': 'nfst00910312'},
#     {'name': 'Radar', 'id': 'nfst01086712'},
#     {'name': 'Groundwater--Pollution', 'id': 'nfst00948250'},
#     {'name': 'Gulf of Mexico--Corpus Christi Bay', 'id': 'nfst01241945'},
#     {'name': 'Landslide hazard analysis', 'id': 'nfst00992078'},
#     {'name': 'Underwater gliders', 'id': 'nfst01895749'},
#     {'name': 'Integrated Ocean Observing System (U.S.)', 'id': 'nfst01672049'},
#     {'name': 'Tidal currents', 'id': 'nfst01150760'},
#     {'name': 'Heat--Transmission', 'id': 'nfst00953826'},
#     {'name': 'Estuarine oceanography', 'id': 'nfst00915704'},
#     {'name': 'Hydrogeology--Mathematical models', 'id': 'nfst00965086'},
#     {'name': 'Soil physics', 'id': 'nfst01124537'},
#     {'name': 'Zone of aeration', 'id': 'nfst01184607'},
#     {'name': 'Oceanography--Observations--Data processing',
#      'id': 'nfst01043700'},
#     {'name': 'Oceanography--Observations', 'id': 'nfst01043699'},
#     {'name': 'Groundwater', 'id': 'nfst00948209'},
#     {'name': 'Gulf of Mexico--Loop Current', 'id': 'nfst01919631'},
#     {'name': 'Continental shelf', 'id': 'nfst00876676'},
#     {'name': 'Water resources development', 'id': 'nfst01171955'}]},
#   {'name': 'Mays Business School',
#    'id': 'n568e1695',
#    'departments': [{'name': 'Mays Graduate Programs', 'id': 'ne64df2f6'},
#     {'name': 'Information and Operations Management', 'id': 'nf8725ed5'},
#     {'name': 'Accounting', 'id': 'n545e2322'},
#     {'name': 'Mays Student Transformation Center', 'id': 'nb4f41ed4'},
#     {'name': 'Finance', 'id': 'nf08b8ede'},
#     {'name': 'Management', 'id': 'n677b2c9f'},
#     {'name': 'Marketing', 'id': 'n11126ef6'}],
#    'research_areas': [{'name': 'International business enterprises--Taxation--Law and legislation',
#      'id': 'nfst00976847'},
#     {'name': 'Transfer pricing', 'id': 'nfst01154627'},
#     {'name': 'Learning, Leadership, Organization Development',
#      'id': 'nfst00994826'},
#     {'name': 'Learning', 'id': 'nfst00994826'},
#     {'name': 'Corporations', 'id': 'nfst00879777'},
#     {'name': 'Sustainable development', 'id': 'nfst01139731'},
#     {'name': 'Teaching', 'id': 'nfst01144565'},
#     {'name': 'Women--Social conditions', 'id': 'nfst01176947'},
#     {'name': 'International business enterprises', 'id': 'nfst00976774'},
#     {'name': 'Commercial policy', 'id': 'nfst00869569'},
#     {'name': 'Corruption', 'id': 'nfst01352550'},
#     {'name': 'Industrial policy', 'id': 'nfst00971433'},
#     {'name': 'Human trafficking', 'id': 'nfst01739818'}]},
#   {'name': 'Texas A&M University at Qatar',
#    'id': 'ned9805ff',
#    'departments': [{'name': 'Science (Qatar)', 'id': 'n87eb6cfe'},
#     {'name': 'Mechanical Engineering (Qatar)', 'id': 'n69d9e085'},
#     {'name': 'Electrical and Computer Engineering (Qatar)', 'id': 'n5efbf3f4'},
#     {'name': 'Chemical Engineering (Qatar)', 'id': 'nec186a90'},
#     {'name': 'Petroleum Engineering (Qatar)', 'id': 'n783f4dfe'},
#     {'name': 'Liberal Arts (Qatar)', 'id': 'n1a0f47cd'}],
#    'research_areas': [{'name': 'Electrocatalysis', 'id': 'nfst00906358'},
#     {'name': 'Speech perception', 'id': 'nfst01129230'},
#     {'name': 'Art', 'id': 'nfst00815177'},
#     {'name': 'Photovoltaic power generation', 'id': 'nfst01062167'},
#     {'name': 'Speech processing systems--Computer programs',
#      'id': 'nfst01129244'},
#     {'name': 'Youth', 'id': 'nfst01183341'},
#     {'name': 'Neurosciences', 'id': 'nfst01036509'},
#     {'name': 'Microgrids (Smart power grids)', 'id': 'nfst01938639'},
#     {'name': 'Cochlear implants', 'id': 'nfst00866081'},
#     {'name': 'Water', 'id': 'nfst01171139'},
#     {'name': 'Power electronics', 'id': 'nfst01074238'},
#     {'name': 'Renewable energy sources', 'id': 'nfst01094570'},
#     {'name': 'South Asia', 'id': 'nfst01244520'},
#     {'name': 'Electric power systems', 'id': 'nfst00905529'},
#     {'name': 'Popular culture', 'id': 'nfst01071344'},
#     {'name': 'Adolescence', 'id': 'nfst00796984'},
#     {'name': 'Chemical engineering', 'id': 'nfst00852893'}]},
#   {'name': 'Texas A&M AgriLIFE Extension',
#    'id': 'na57124aa',
#    'departments': [{'name': 'Dallas Research and Extension Center',
#      'id': 'n869daec6'},
#     {'name': 'Temple Research and Extension Center', 'id': 'n1bd509c0'},
#     {'name': 'Corpus Christi Research and Extension Center',
#      'id': 'n92e9ab11'},
#     {'name': 'El Paso Research and Extension Center', 'id': 'nddc73641'},
#     {'name': 'Stephenville Research and Extension Center', 'id': 'n2b12a3f3'},
#     {'name': 'Temple-Blackland Research and Extension Center',
#      'id': 'nd32870de'},
#     {'name': 'Weslaco Research and Extension Center', 'id': 'n8f5fab75'},
#     {'name': 'Overton Research and Extension Center', 'id': 'n92a3b78c'},
#     {'name': 'Vernon Research and Extension Center', 'id': 'nba884f19'},
#     {'name': 'Beaumont Research and Extension Center', 'id': 'n0ca7962d'},
#     {'name': 'Amarillo Research and Extension Center', 'id': 'ncecc80b2'},
#     {'name': 'Lubbock Research and Extension Center', 'id': 'ncc736b32'},
#     {'name': 'Uvalde Research and Extension Center', 'id': 'ncbb3f3d9'},
#     {'name': 'San Angelo Research and Extension Center', 'id': 'n2b0a4f66'}],
#    'research_areas': [{'name': 'Prescribed burning--Research',
#      'id': 'nfst01075644'},
#     {'name': 'Grazing--Management', 'id': 'nfst00946989'},
#     {'name': 'Transportation', 'id': 'nfst01155007'},
#     {'name': 'Prescribed burning', 'id': 'nfst01075637'},
#     {'name': 'Rangelands--Fire management', 'id': 'nfst01089880'},
#     {'name': 'Environmental', 'id': 'nfst00901476'},
#     {'name': 'Ecology', 'id': 'nfst00901476'},
#     {'name': 'Environment', 'id': 'nfst00901476'},
#     {'name': 'Community development', 'id': 'nfst00870818'},
#     {'name': 'Plants--Microbiology', 'id': 'nfst01066055'},
#     {'name': 'Rural development', 'id': 'nfst01101498'},
#     {'name': 'Strategic planning', 'id': 'nfst01134371'},
#     {'name': 'Range management', 'id': 'nfst01089831'},
#     {'name': 'Regional planning', 'id': 'nfst01093120'},
#     {'name': 'Brush--Control', 'id': 'nfst00839867'},
#     {'name': 'Plant diseases', 'id': 'nfst01065378'},
#     {'name': 'Economic policy', 'id': 'nfst00902025'}]},
#   {'name': 'Texas A&M Transportation Institute (TTI)',
#    'id': 'n364ccf55',
#    'departments': [{'name': 'Center for Transportation Safety',
#      'id': 'n651fcd8f'},
#     {'name': 'Center for Railway Research', 'id': 'n6ea2b5f6'}],
#    'research_areas': [{'name': 'Roads--Safety measures', 'id': 'nfst01098774'},
#     {'name': 'Finite element method', 'id': 'nfst00924897'},
#     {'name': 'Fracture mechanics', 'id': 'nfst00933536'},
#     {'name': 'Multiscale modeling', 'id': 'nfst01763130'},
#     {'name': 'Automobiles--Crashworthiness', 'id': 'nfst00823354'},
#     {'name': 'Motor vehicles--Dynamics--Computer simulation',
#      'id': 'nfst01027767'}]},
#   {'name': 'College of Education and Human Development',
#    'id': 'nf01ba483',
#    'departments': [{'name': 'Educational Psychology', 'id': 'n05013a31'},
#     {'name': 'Health and Kinesiology', 'id': 'n5f8cc79d'},
#     {'name': 'Teaching, Learning and Culture', 'id': 'n833d3ed2'},
#     {'name': 'Educational Administration and Human Resource Development',
#      'id': 'n0ea14cc2'},
#     {'name': 'Aggie STEM', 'id': 'nb89b5d43'}],
#    'research_areas': [{'name': 'Emotions and cognition', 'id': 'nfst00908858'},
#     {'name': 'Parenting', 'id': 'nfst01053407'},
#     {'name': 'Personality', 'id': 'nfst01058667'},
#     {'name': 'Developmental psychology', 'id': 'nfst00891816'},
#     {'name': 'Teachers', 'id': 'nfst01144248'},
#     {'name': 'Teacher-student relationships', 'id': 'nfst01144236'},
#     {'name': 'Reading', 'id': 'nfst01090626'},
#     {'name': 'Social change', 'id': 'nfst01122310'},
#     {'name': 'Teachers--Training of', 'id': 'nfst01144404'},
#     {'name': 'Context effects (Psychology)', 'id': 'nfst00876662'},
#     {'name': 'Self-control', 'id': 'nfst01111538'},
#     {'name': 'Temperament', 'id': 'nfst01147294'},
#     {'name': 'Education--Curricula', 'id': 'nfst00902556'},
#     {'name': 'Child development', 'id': 'nfst00854393'},
#     {'name': 'Human Resource Development and African Americans',
#      'id': 'nfst00902499'},
#     {'name': 'Education', 'id': 'nfst00902499'},
#     {'name': 'Empathy', 'id': 'nfst00908880'},
#     {'name': 'International education', 'id': 'nfst00976924'},
#     {'name': 'Empathy in children', 'id': 'nfst01740391'},
#     {'name': 'Writing', 'id': 'nfst01181638'},
#     {'name': 'Learning, Leadership, Organization Development',
#      'id': 'nfst00994826'},
#     {'name': 'Learning', 'id': 'nfst00994826'},
#     {'name': 'College teachers', 'id': 'nfst00868114'},
#     {'name': 'Teaching', 'id': 'nfst01144565'},
#     {'name': 'Literacy', 'id': 'nfst00999859'},
#     {'name': 'Resilience (Personality trait)', 'id': 'nfst01095573'},
#     {'name': 'Emotions in children', 'id': 'nfst00908863'},
#     {'name': 'Executive functions (Neuropsychology)', 'id': 'nfst01893671'}]},
#   {'name': 'College of Architecture',
#    'id': 'n4b0538ce',
#    'departments': [{'name': 'Center for Health Systems and Design',
#      'id': 'naaf1953a'},
#     {'name': 'Construction Science', 'id': 'nb3270776'},
#     {'name': 'Architecture', 'id': 'n4e979062'},
#     {'name': 'Institute for Applied Creativity', 'id': 'n31761231'},
#     {'name': 'Landscape Architecture and Urban Planning', 'id': 'n428d21e0'},
#     {'name': 'Visualization', 'id': 'nae89eb87'},
#     {'name': 'Hazard Reduction and Recovery Center', 'id': 'n014501e7'}],
#    'research_areas': []},
#   {'name': 'College of Veterinary Medicine and Biomedical Sciences',
#    'id': 'n1978f11a',
#    'departments': [{'name': 'Large Animal Clinical Sciences',
#      'id': 'n69c7d117'},
#     {'name': 'Veterinary Integrative Biosciences', 'id': 'nfff9d34d'},
#     {'name': 'Small Animal Clinical Sciences', 'id': 'n3334b89b'},
#     {'name': 'Veterinary Pathobiology', 'id': 'n3af9f727'},
#     {'name': 'Veterinary Physiology and Pharmacology', 'id': 'na15adf32'}],
#    'research_areas': [{'name': 'Beef cattle', 'id': 'nfst00829613'},
#     {'name': 'Dairy cattle', 'id': 'nfst00886806'},
#     {'name': 'Reproductive biology', 'id': 'nfst01791046'},
#     {'name': 'Genetics', 'id': 'nfst00940117'},
#     {'name': 'Educational technology', 'id': 'nfst00903623'},
#     {'name': 'Toxicology', 'id': 'nfst01153364'},
#     {'name': 'Cellular signal transduction', 'id': 'nfst00850288'},
#     {'name': 'Immunology', 'id': 'nfst00968006'}]},
#   {'name': 'Institute for Sustainable Communities',
#    'id': 'n2276c6af',
#    'departments': [],
#    'research_areas': []},
#   {'name': 'Health Science Center',
#    'id': 'n043bc62c',
#    'departments': [{'name': 'Rural and Community Health Institute',
#      'id': 'n63d04a90'},
#     {'name': 'College of Dentistry', 'id': 'n7b97a518'},
#     {'name': 'School of Public Health', 'id': 'n7fa1fd47'},
#     {'name': 'Global Institute for Hispanic Health', 'id': 'nb74793be'},
#     {'name': 'College of Medicine', 'id': 'nd14d726a'},
#     {'name': 'Irma Lerma Rangel College of Pharmacy', 'id': 'n1f1795b1'},
#     {'name': 'College of Nursing', 'id': 'n699ce527'}],
#    'research_areas': [{'name': 'Face--Surgery', 'id': 'nfst00919548'},
#     {'name': 'Exercise', 'id': 'nfst00917991'},
#     {'name': 'Health services accessibility', 'id': 'nfst00953278'},
#     {'name': 'Molecular toxicology', 'id': 'nfst01024862'},
#     {'name': 'Wounds and injuries', 'id': 'nfst01181488'},
#     {'name': 'Molecular genetics', 'id': 'nfst01024797'},
#     {'name': 'Surgery, Plastic', 'id': 'nfst01139417'},
#     {'name': 'Biochemistry', 'id': 'nfst00831961'},
#     {'name': 'Medical genetics', 'id': 'nfst01014133'},
#     {'name': 'Pharmacology', 'id': 'nfst01060259'},
#     {'name': 'Lifestyles--Health aspects', 'id': 'nfst00998421'},
#     {'name': 'Genotype-environment interaction', 'id': 'nfst00940233'},
#     {'name': 'Community development', 'id': 'nfst00870818'},
#     {'name': 'Public health', 'id': 'nfst01082238'},
#     {'name': 'Public health disparities', 'id': 'nfst01082238'},
#     {'name': 'Molecular biology', 'id': 'nfst01024734'},
#     {'name': 'Transplantation of organs, tissues, etc.', 'id': 'nfst01154919'},
#     {'name': 'Molecular pharmacology', 'id': 'nfst01024822'},
#     {'name': 'Tissue engineering', 'id': 'nfst01151484'}]},
#   {'name': 'College of Liberal Arts',
#    'id': 'n70d8cedd',
#    'departments': [{'name': 'Melbern G. Glasscock Center for Humanities Research',
#      'id': 'n9841a617'},
#     {'name': 'Performance Studies', 'id': 'n155828f3'},
#     {'name': 'Economics', 'id': 'n5bb716ca'},
#     {'name': 'International Studies', 'id': 'n615e3613'},
#     {'name': 'Anthropology', 'id': 'n0f7aa775'},
#     {'name': 'Sociology', 'id': 'n8dcc5392'},
#     {'name': 'Political Science', 'id': 'n7b18cfce'},
#     {'name': 'Psychological and Brain Sciences', 'id': 'n54556104'},
#     {'name': 'Women & Gender Studies', 'id': 'n3e1d7d9c'},
#     {'name': 'English', 'id': 'nbc3b05cc'},
#     {'name': 'Africana Studies', 'id': 'n0c1e41a4'},
#     {'name': 'Philosophy', 'id': 'n1ee5508a'},
#     {'name': 'Communication', 'id': 'n11e515bb'},
#     {'name': 'History', 'id': 'n5362e018'},
#     {'name': 'Hispanic Studies', 'id': 'n6d109098'}],
#    'research_areas': [{'name': 'Italy', 'id': 'nfst01204565'},
#     {'name': 'Women in development', 'id': 'nfst01177865'},
#     {'name': 'History', 'id': 'nfst01411628'},
#     {'name': 'Geography', 'id': 'nfst00940469'},
#     {'name': 'Education, Higher--Administration', 'id': 'nfst00903010'},
#     {'name': 'Printing', 'id': 'nfst01076612'},
#     {'name': 'Emigration and immigration', 'id': 'nfst00908690'},
#     {'name': 'Religion and science', 'id': 'nfst01093848'},
#     {'name': 'Cartography', 'id': 'nfst00848025'},
#     {'name': 'Communication', 'id': 'nfst00869952'},
#     {'name': 'Access to Higher Education Diploma', 'id': 'nfst01982599'},
#     {'name': 'Human Resource Development and African Americans',
#      'id': 'nfst00902499'},
#     {'name': 'Education', 'id': 'nfst00902499'},
#     {'name': 'Evangelicalism', 'id': 'nfst00917002'},
#     {'name': 'Information policy', 'id': 'nfst00972596'},
#     {'name': 'History--Religious aspects--Christianity', 'id': 'nfst00958274'},
#     {'name': 'Climatic changes--Social aspects', 'id': 'nfst00864268'},
#     {'name': 'Military history, Modern', 'id': 'nfst01021239'},
#     {'name': 'Economic development', 'id': 'nfst00901785'},
#     {'name': 'France', 'id': 'nfst01204289'},
#     {'name': 'Church history', 'id': 'nfst01411629'},
#     {'name': 'Motion pictures', 'id': 'nfst01027285'},
#     {'name': 'Senegal', 'id': 'nfst01204328'},
#     {'name': 'Immigrant students', 'id': 'nfst01920560'},
#     {'name': 'College students', 'id': 'nfst00867976'},
#     {'name': 'Manuscripts', 'id': 'nfst01424060'},
#     {'name': 'Virtual reality', 'id': 'nfst01167688'},
#     {'name': 'Digital mapping', 'id': 'nfst00893710'},
#     {'name': 'Military history', 'id': 'nfst01411630'},
#     {'name': 'Women writers', 'id': 'nfst01402373'},
#     {'name': 'Law', 'id': 'nfst00993678'}]}]}

# %%
department_struct = {}

for college in structure_data['colleges']:
    try:
        departments = [department['name'] for department in college['departments']]
    except KeyError:
        departments = []

    department_struct[college['name']] = departments

with open('./dicts/structure/departments.json', 'w') as outfile:
    json.dump(department_struct, outfile, indent=4)

# %%
research_struct = {}

for college in structure_data['colleges']:
    try:
        departments = {department['name']: [] for department in college['departments']}
    except KeyError:
        departments = {}
    else:
        try:
            department_dicts = [department for department in college['departments']]
            departments[department_dicts['name']: get_api_dict(api_base + department_dicts['id'])]

        except KeyError:
            divisions = []
            print(divisions)

    research_struct[college['name']] = departments

# with open('./dicts/structure/departments.json', 'w') as outfile:
#     json.dump(department_struct, outfile, indent=4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/abibstopher/Documents/Spring 2022/TAMIDS/Code/Scholars@TAMU Data/pulling_more_data.ipynb Cell 29' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/Users/abibstopher/Documents/Spring%202022/TAMIDS/Code/Scholars%40TAMU%20Data/pulling_more_data.ipynb#ch0000035?line=8'>9</a> if departments:
#      <a href='vscode-notebook-cell:/Users/abibstopher/Documents/Spring%202022/TAMIDS/Code/Scholars%40TAMU%20Data/pulling_more_data.ipynb#ch0000035?line=9'>10</a>     try:
# ---> <a href='vscode-notebook-cell:/Users/abibstopher/Documents/Spring%202022/TAMIDS/Code/Scholars%40TAMU%20Data/pulling_more_data.ipynb#ch0000035?line=10'>11</a>         divisions = [division['label'] for division in college['departments']['api_data']['hasSubOrganizations']]
#      <a href='vscode-notebook-cell:/Users/abibstopher/Documents/Spring%202022/TAMIDS/Code/Scholars%40TAMU%20Data/pulling_more_data.ipynb#ch0000035?line=11'>12</a>     except KeyError:
#      <a href='vscode-notebook-cell:/Users/abibstopher/Documents/Spring%202022/TAMIDS/Code/Scholars%40TAMU%20Data/pulling_more_data.ipynb#ch0000035?line=12'>13</a>         divisions = []
#
# TypeError: list indices must be integers or slices, not str

# %%
with open('./test1.json', 'w') as outfile:
    json.dump(tamu_structure, outfile, indent=4)
with open('./test2.json', 'w') as outfile:
    json.dump(structure_data, outfile, indent=4)
