# %% [markdown]
# # Exploring Natural Language Processing
# **Filename:** exploring_nlp.ipynb
# **Path:** TAMIDS/Code/Scholars@TAMU Data/exploring_nlp.ipynb
# **Created Date:** 05 April 2022, 01:53
#
# Learning how to use NLP.

# %%
from IPython.display import Markdown, display, HTML
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from gensim import corpora, models, similarities
import jieba

pd.options.display.float_format = '{:,.3f}'.format
plt.style.use('seaborn-darkgrid')

# General Markdown Formatting Functions

def printmd(string, level=1):
    header_level = '#'*level + ' '
    display(Markdown(header_level + string))

# %% [markdown]
# ## Loading the Data

# %%
people = pd.read_pickle('../../Data/Scholars@TAMU/my_api_calls/people_df.pickle')
publications = pd.read_pickle('../../Data/Scholars@TAMU/my_api_calls/publications_df.pickle')

# %%
publications.sample(n=50)
# Out:
#                                            author_ids  \
# publication_api_id
# n32475SE                                  [na2a37577]
# n479824SE                                 [nfc1740f1]
# n416669SE                                 [n40dbead6]
# n346165SE                                 [nfa1a6351]
# n44068SE                                  [n279be03a]
# n171776SE                                         NaN
# n47847SE                                  [n67571474]
# n418013SE                                 [n2b854905]
# n341979SE                                 [n1d2223c8]
# n468054SE                      [n6ba4cec9, n042bccf8]
# n139089SE                                 [n262ead89]
# n95414SE                                          NaN
# n220433SE                                 [nc67f3bb1]
# n340105SE                                         NaN
# n583772SE                                 [n13d7ac3c]
# n226501SE                                 [n394dc57a]
# n344928SE           [n740165c8, n263e1c5b, n3b8a47b0]
# n167623SE                                 [nd695d1d9]
# n295153SE                                 [n3fbb59f8]
# n520828SE                                 [nc82bc997]
# n285983SE                                 [n433248e7]
# n342438SE                                 [n807b8d90]
# n516700SE                                 [n2bf365ca]
# n478973SE                                 [nc0a24d92]
# n311894SE                                 [n0905ed4e]
# n356774SE                                 [n92575b4f]
# n491370SE                                 [n00f3c2fd]
# n219104SE                                         NaN
# n393927SE                                 [n6ec795d9]
# n74819SE                                  [n90385563]
# n213660SE                                         NaN
# n214061SE                                         NaN
# n120548SE                                 [ne3b7e44f]
# n129810SE                                 [ndd7ffe32]
# n37744SE                                  [ndd473437]
# n44452SE                                  [n3e685bb1]
# n226064SE                                 [nd6dc5153]
# n152093SE                      [n36a51a43, n90385563]
# n63787SE                                  [n433248e7]
# n435851SE                                 [n5e728236]
# n84484SE                                          NaN
# n188197SE                                 [nfdda43fb]
# n290909SE                                         NaN
# n282704SE                                         NaN
# n334900SE                                 [n7a63dbe7]
# n378987SE                                 [n4e390d47]
# n410062SE                                 [ne4a280f0]
# n135434SE                      [n40c4fb25, n44e55b75]
# n316521SE                                 [ndc4f344f]
# n88649SE                                  [n640c528f]
#
#                                           author_uins  year publication_type  \
# publication_api_id
# n32475SE                                  [702002692]  2001  Journal Article
# n479824SE                                 [930004302]  2001       Conference
# n416669SE                                 [823002420]  2005  Journal Article
# n346165SE                                 [302002850]  2015  Journal Article
# n44068SE                                  [601003904]  2006  Journal Article
# n171776SE                                         NaN   NaN              NaN
# n47847SE                                  [103000260]  2009  Journal Article
# n418013SE                                 [723009901]  2012  Journal Article
# n341979SE                                 [302002950]  2010  Journal Article
# n468054SE                      [226005058, 917005862]  2020       Conference
# n139089SE                                 [517006217]  2008       Conference
# n95414SE                                          NaN   NaN              NaN
# n220433SE                                 [717001651]  2016             Book
# n340105SE                                         NaN   NaN              NaN
# n583772SE                                 [802001572]  2019       Conference
# n226501SE                                 [202003299]  2010       Conference
# n344928SE           [402005459, 101009975, 115008595]  2014  Journal Article
# n167623SE                                 [917000989]  2014          Chapter
# n295153SE                                 [602004661]  1986       Conference
# n520828SE                                 [414005577]  2021  Journal Article
# n285983SE                                 [301005096]  2015       Conference
# n342438SE                                 [117001856]  2005       Conference
# n516700SE                                 [128004639]  2013  Journal Article
# n478973SE                                 [230009149]  2002       Conference
# n311894SE                                 [501001216]  2007  Journal Article
# n356774SE                                 [623001040]  2017  Journal Article
# n491370SE                                 [728004288]  2007  Journal Article
# n219104SE                                         NaN   NaN              NaN
# n393927SE                                 [327007925]  2011       Conference
# n74819SE                                  [202007503]  2001  Journal Article
# n213660SE                                         NaN   NaN              NaN
# n214061SE                                         NaN   NaN              NaN
# n120548SE                                 [617008321]  1993  Journal Article
# n129810SE                                 [403009270]  1996  Journal Article
# n37744SE                                  [801004894]  2006  Journal Article
# n44452SE                                  [202003704]  2008  Journal Article
# n226064SE                                 [705001614]  2003  Journal Article
# n152093SE                      [102006528, 202007503]  2017  Journal Article
# n63787SE                                  [301005096]  1987  Journal Article
# n435851SE                                 [402002635]  2018          Chapter
# n84484SE                                          NaN   NaN              NaN
# n188197SE                                 [801004730]  2004       Conference
# n290909SE                                         NaN   NaN              NaN
# n282704SE                                         NaN   NaN              NaN
# n334900SE                                 [223006891]  2006       Conference
# n378987SE                                 [924002384]  2011  Journal Article
# n410062SE                                 [523000788]  2019  Journal Article
# n135434SE                      [501001113, 202005361]  1990  Journal Article
# n316521SE                                 [701002148]  1986       Conference
# n88649SE                                  [901007639]  1993  Journal Article
#
#                                                     publication_title  \
# publication_api_id
# n32475SE            Phase-matching condition between acoustic and ...
# n479824SE              Fiber-Based Electro-Optic Field Imaging System
# n416669SE           Vicksburg is the Key: The Struggle for the Mis...
# n346165SE           Effects of A. nodosum seaweed extracts on spin...
# n44068SE            Entanglement conditions for two-mode states: A...
# n171776SE                                                         NaN
# n47847SE            Prenatal lead exposure enhances methamphetamin...
# n418013SE           Superior activity of MnOx-CeO2/TiO2 catalyst f...
# n341979SE           Study on retrograde extrapolation of blood alc...
# n468054SE           Microbiomes of a corallivore (Hermodice carunc...
# n139089SE           Chi-squared distribution approximation for pro...
# n95414SE                                                          NaN
# n220433SE             Forms of Address in the Spanish of the Americas
# n340105SE                                                         NaN
# n583772SE           Turbulent / Non-Turbulent Interface and Unifor...
# n226501SE             Optical I/O Technology for Tera-Scale Computing
# n344928SE           The effect of substrate moisture content on gr...
# n167623SE                     Microorganisms Found in the Environment
# n295153SE           HUMAN EPIDERMAL ENZYME PREPARATIONS CAN ELONGA...
# n520828SE           Listeria adhesion protein-expressing bioengine...
# n285983SE                Changing Surface Water Availability in Texas
# n342438SE           Parasitism levels in Orgyia leucostigma feedin...
# n516700SE                  The supraview of return predictive signals
# n478973SE           Design of state-space-based control algorithms...
# n311894SE           Managing for desired experiences and site pref...
# n356774SE           Identification of potent virtual leads and ADM...
# n491370SE           Electric field enhancement between two Si micr...
# n219104SE                                                         NaN
# n393927SE           Theoretical and Experimental Comparison of Two...
# n74819SE            An Engineered Transthyretin Monomer that Is No...
# n213660SE                                                         NaN
# n214061SE                                                         NaN
# n120548SE           Diphenylphosphin-substituiertes, chirales Poly...
# n129810SE           Bayesian reconstruction and use of anatomical ...
# n37744SE            Origin of the Single Chain Magnet Behavior of ...
# n44452SE            Multiple steps and multiple excitations in pho...
# n226064SE           In-line liquid-crystal microcell polarimeter f...
# n152093SE           Glyoxylate detoxification is an essential func...
# n63787SE                                Reservoir Management in Texas
# n435851SE                                              Basic Concepts
# n84484SE                                                          NaN
# n188197SE           Tight lower bounds for certain parameterized N...
# n290909SE                                                         NaN
# n282704SE                                                         NaN
# n334900SE           Sulforaphane inhibits HDAC activity in prostat...
# n378987SE           Why should the Littlewoodâ€“Richardson Rule be...
# n410062SE                                      Pathology in Practice.
# n135434SE           Using an expert system to identify a well-test...
# n316521SE           AUTONOMIC AND SELF-REPORT MEASURES OF PHYSIOLO...
# n88649SE            Circadian regulation of c-fos expression in th...
#
#                                                               keyword  \
# publication_api_id
# n32475SE                                       [Optics, Spectroscopy]
# n479824SE                                                         NaN
# n416669SE                                                         NaN
# n346165SE                                               [Agriculture]
# n44068SE                                            [Optics, Physics]
# n171776SE                                                         NaN
# n47847SE            [Behavioral Sciences, Neurosciences & Neurolog...
# n418013SE                                    [Chemistry, Engineering]
# n341979SE                                                         NaN
# n468054SE                                          [Zoology, Zoology]
# n139089SE           [Computer Science, Engineering, Telecommunicat...
# n95414SE                                                          NaN
# n220433SE                                                         NaN
# n340105SE                                                         NaN
# n583772SE                                                         NaN
# n226501SE                                                         NaN
# n344928SE                                                         NaN
# n167623SE                                                         NaN
# n295153SE                          [Research & Experimental Medicine]
# n520828SE                                                       [nan]
# n285983SE                                                         NaN
# n342438SE                                                         NaN
# n516700SE                                                         NaN
# n478973SE                                                         NaN
# n311894SE                          [Environmental Sciences & Ecology]
# n356774SE           [Biochemistry & Molecular Biology, Computer Sc...
# n491370SE                                                    [Optics]
# n219104SE                                                         NaN
# n393927SE                                                         NaN
# n74819SE                           [Biochemistry & Molecular Biology]
# n213660SE                                                         NaN
# n214061SE                                                         NaN
# n120548SE                                                 [Chemistry]
# n129810SE                                                         NaN
# n37744SE                                         [Chemistry, Physics]
# n44452SE                                         [Chemistry, Physics]
# n226064SE                                                         NaN
# n152093SE           [Science & Technology - Other Topics, Science ...
# n63787SE                               [Engineering, Water Resources]
# n435851SE                                                         NaN
# n84484SE                                                          NaN
# n188197SE                                          [Computer Science]
# n290909SE                                                         NaN
# n282704SE                                                         NaN
# n334900SE           [Biochemistry & Molecular Biology, Life Scienc...
# n378987SE                                               [Mathematics]
# n410062SE                                                       [nan]
# n135434SE                                                         NaN
# n316521SE           [Psychology, Neurosciences & Neurology, Physio...
# n88649SE            [Life Sciences & Biomedicine - Other Topics, P...
#
#                    un_sustainable_development_goals  \
# publication_api_id
# n32475SE                                        NaN
# n479824SE                                       NaN
# n416669SE                                       NaN
# n346165SE                                       NaN
# n44068SE                                        NaN
# n171776SE                                       NaN
# n47847SE                                        NaN
# n418013SE                                       NaN
# n341979SE                                       NaN
# n468054SE                                       NaN
# n139089SE           [7 Affordable and Clean Energy]
# n95414SE                                        NaN
# n220433SE                                       NaN
# n340105SE                                       NaN
# n583772SE                                       NaN
# n226501SE           [7 Affordable and Clean Energy]
# n344928SE                                       NaN
# n167623SE                                       NaN
# n295153SE                                       NaN
# n520828SE            [3 Good Health and Well-Being]
# n285983SE                                       NaN
# n342438SE            [3 Good Health and Well-Being]
# n516700SE                                       NaN
# n478973SE                                       NaN
# n311894SE                                       NaN
# n356774SE                                       NaN
# n491370SE                                       NaN
# n219104SE                                       NaN
# n393927SE           [7 Affordable and Clean Energy]
# n74819SE                                        NaN
# n213660SE                                       NaN
# n214061SE                                       NaN
# n120548SE                                       NaN
# n129810SE                                       NaN
# n37744SE                                        NaN
# n44452SE                                        NaN
# n226064SE                                       NaN
# n152093SE                                       NaN
# n63787SE                                        NaN
# n435851SE                                       NaN
# n84484SE                                        NaN
# n188197SE                                       NaN
# n290909SE                                       NaN
# n282704SE                                       NaN
# n334900SE                                       NaN
# n378987SE                                       NaN
# n410062SE                                       NaN
# n135434SE                                       NaN
# n316521SE                                       NaN
# n88649SE                                        NaN
#
#                                                   author_organization  \
# publication_api_id
# n32475SE            [Texas A and M University, IBM Almaden Researc...
# n479824SE                                                         NaN
# n416669SE                                                         NaN
# n346165SE                                  [Texas A and M University]
# n44068SE                   [Hunter College, Texas A and M University]
# n171776SE           [Oregon State University, Texas A and M Univer...
# n47847SE                                   [Texas A and M University]
# n418013SE             [Huazhong University of Science and Technology]
# n341979SE                                [Ministry of Justice, China]
# n468054SE                                                         NaN
# n139089SE           [TELECOM ParisTech, Texas A and M University a...
# n95414SE            [Nanjing University, Wayne State University Sc...
# n220433SE                                                         NaN
# n340105SE                 [Inha University, Incheon, Inha University]
# n583772SE                                                         NaN
# n226501SE           [Intel Corporation, Texas A and M University, ...
# n344928SE           [Texas A and M University, Texas A and M Syste...
# n167623SE                                  [Texas A and M University]
# n295153SE                                                         NaN
# n520828SE                                                         NaN
# n285983SE                                  [Texas A and M University]
# n342438SE           [University of Maryland, American Vineyard Fou...
# n516700SE                                                         NaN
# n478973SE                                                         NaN
# n311894SE           [Texas A and M University, West Virginia Unive...
# n356774SE           [Umm Al Qura University, Texas A and M Univers...
# n491370SE                                                         NaN
# n219104SE           [Vanderbilt University, The University of Geor...
# n393927SE                                                         NaN
# n74819SE            [Scripps Research Institute, Texas A and M Uni...
# n213660SE                                  [Texas A and M University]
# n214061SE           [Texas A and M University, Oregon State Univer...
# n120548SE                            [Technical University of Munich]
# n129810SE           [Duke University School of Medicine, Duke Univ...
# n37744SE            [Institute of Applied Physics Academy of Scien...
# n44452SE                                   [Texas A and M University]
# n226064SE           [Nokia Bell Labs, University of Minnesota Twin...
# n152093SE           [Weill Cornell Medical College, Texas A and M ...
# n63787SE                                   [Texas A and M University]
# n435851SE                                                         NaN
# n84484SE                                   [Texas A and M University]
# n188197SE           [Texas A and M University, Tel Aviv University...
# n290909SE                                  [Texas A and M University]
# n282704SE                                    [Sungyunkwan University]
# n334900SE                                                         NaN
# n378987SE           [Yale University, National University of Singa...
# n410062SE                                                         NaN
# n135434SE                                  [Texas A and M University]
# n316521SE                                                         NaN
# n88649SE            [University of Rochester School of Medicine an...
#
#                                                           author_city  \
# publication_api_id
# n32475SE                                  [College Station, San Jose]
# n479824SE                                                         NaN
# n416669SE                                                         NaN
# n346165SE                                           [College Station]
# n44068SE                                  [New York, College Station]
# n171776SE                                [Corvallis, College Station]
# n47847SE                                            [College Station]
# n418013SE                                                     [Wuhan]
# n341979SE                                                  [Shanghai]
# n468054SE                                                         NaN
# n139089SE                  [Paris Cedex 13, Doha, Paris, Paris, Doha]
# n95414SE                          [Nanjing, Detroit, College Station]
# n220433SE                                                         NaN
# n340105SE                                          [Incheon, Incheon]
# n583772SE                                                         NaN
# n226501SE             [Santa Clara, College Station, College Station]
# n344928SE                 [College Station, El Paso, College Station]
# n167623SE                                           [College Station]
# n295153SE                                                         NaN
# n520828SE                                                         NaN
# n285983SE                                           [College Station]
# n342438SE                                        [College Park, Napa]
# n516700SE                                                         NaN
# n478973SE                                                         NaN
# n311894SE                               [College Station, Morgantown]
# n356774SE                  [Makkah, Kingsville, Makkah al Mukarramah]
# n491370SE                                                         NaN
# n219104SE                                         [Nashville, Athens]
# n393927SE                                                         NaN
# n74819SE                                 [San Diego, College Station]
# n213660SE                                           [College Station]
# n214061SE           [College Station, Corvallis, Kent, Seattle, Wa...
# n120548SE                                                    [Munich]
# n129810SE                                            [Durham, Durham]
# n37744SE            [Chisinau, Chisinau, Chisinau, Chisinau, Fuzho...
# n44452SE                                            [College Station]
# n226064SE                                [Murray, Minneapolis, Upton]
# n152093SE                    [New York, College Station, Los Angeles]
# n63787SE                                            [College Station]
# n435851SE                                                         NaN
# n84484SE                                            [College Station]
# n188197SE           [College Station, Tel Aviv-Yafo, Callaghan, At...
# n290909SE                                           [College Station]
# n282704SE                                                     [Suwon]
# n334900SE                                                         NaN
# n378987SE                      [New Haven, Singapore City, Singapore]
# n410062SE                                                         NaN
# n135434SE                                           [College Station]
# n316521SE                                                         NaN
# n88649SE                 [Rochester, Rochester, Rochester, Rochester]
#
#                                                        author_country  \
# publication_api_id
# n32475SE                               [United States, United States]
# n479824SE                                                         NaN
# n416669SE                                                         NaN
# n346165SE                                             [United States]
# n44068SE                               [United States, United States]
# n171776SE                              [United States, United States]
# n47847SE                                              [United States]
# n418013SE                                                     [China]
# n341979SE                                                     [China]
# n468054SE                                                         NaN
# n139089SE                      [France, Qatar, France, France, Qatar]
# n95414SE                        [China, United States, United States]
# n220433SE                                                         NaN
# n340105SE                                  [South Korea, South Korea]
# n583772SE                                                         NaN
# n226501SE               [United States, United States, United States]
# n344928SE               [United States, United States, United States]
# n167623SE                                             [United States]
# n295153SE                                                         NaN
# n520828SE                                                         NaN
# n285983SE                                             [United States]
# n342438SE                              [United States, United States]
# n516700SE                                                         NaN
# n478973SE                                                         NaN
# n311894SE                              [United States, United States]
# n356774SE                 [Saudi Arabia, United States, Saudi Arabia]
# n491370SE                                                         NaN
# n219104SE                              [United States, United States]
# n393927SE                                                         NaN
# n74819SE                               [United States, United States]
# n213660SE                                             [United States]
# n214061SE           [United States, United States, United States, ...
# n120548SE                                                   [Germany]
# n129810SE                              [United States, United States]
# n37744SE            [Moldova, Moldova, Moldova, Moldova, China, Un...
# n44452SE                                              [United States]
# n226064SE               [United States, United States, United States]
# n152093SE               [United States, United States, United States]
# n63787SE                                              [United States]
# n435851SE                                                         NaN
# n84484SE                                              [United States]
# n188197SE           [United States, Israel, Australia, United Stat...
# n290909SE                                             [United States]
# n282704SE                                               [South Korea]
# n334900SE                                                         NaN
# n378987SE                       [United States, Singapore, Singapore]
# n410062SE                                                         NaN
# n135434SE                                             [United States]
# n316521SE                                                         NaN
# n88649SE            [United States, United States, United States, ...
#
#                                                              abstract
# publication_api_id
# n32475SE            A study was performed on the phase-matching co...
# n479824SE                                                        None
# n416669SE                                                        None
# n346165SE           Â© 2014 . Seaweed extracts (SWE) are biodegrad...
# n44068SE            We examine the implications of several recentl...
# n171776SE                                                         NaN
# n47847SE            Adult female rats were exposed to lead-free so...
# n418013SE                                                        None
# n341979SE           Objective: To make the study on retrograde ext...
# n468054SE                                                        None
# n139089SE           This paper addresses the hardware implementati...
# n95414SE                                                          NaN
# n220433SE           This collection in English is meant to reach s...
# n340105SE                                                         NaN
# n583772SE                                                        None
# n226501SE           This paper describes both a near term and a lo...
# n344928SE           A greenhouse study was conducted to quantify t...
# n167623SE           Â© 2015 Elsevier Inc. All rights reserved. Thi...
# n295153SE                                                        None
# n520828SE           Pregnancy is a high-risk factor for foodborne ...
# n285983SE           Â© 2015 ASCE. Texas is characterized by extrem...
# n342438SE           The slow-growth-high-mortality hypothesis prop...
# n516700SE                                                        None
# n478973SE                                                        None
# n311894SE           Fee-fishing involves paying a fee for the priv...
# n356774SE           Towards the design of new class of podophyllot...
# n491370SE           The field enhancement in the gap between two S...
# n219104SE                                                         NaN
# n393927SE           This paper presents performance comparison of ...
# n74819SE            Transthyretin (TTR) is a soluble human plasma ...
# n213660SE                                                         NaN
# n214061SE                                                         NaN
# n120548SE           <jats:p>Chiral polyepichlorohydrin was obtaine...
# n129810SE           A Bayesian method is presented for simultaneou...
# n37744SE            The paper is aimed at the elucidation of the m...
# n44452SE            Detailed understanding of femtosecond-scale ph...
# n226064SE           We report a type of high-speed microcell polar...
# n152093SE           The glyoxylate shunt is a metabolic pathway of...
# n63787SE            An overview of surface water management in Tex...
# n435851SE                                                        None
# n84484SE                                                          NaN
# n188197SE           Based on the framework of parameterized comple...
# n290909SE                                                         NaN
# n282704SE                                                         NaN
# n334900SE                                                        None
# n378987SE           We give a proof of the Littlewood-Richardson R...
# n410062SE                                                        None
# n135434SE           The authors present a new approach that uses a...
# n316521SE                                                        None
# n88649SE            The primary objective of this research was to ...

# %%
compsci = 'n230467SE'
phys = 'n127269SE'
systems = 'n165882SE'
agbuis = 'n188661SE'
histor = 'n51137SE'

# %% [markdown]
# ## nlp

# %%
texts = [publications['abstract'][key] if publications['abstract'][key] else '' for key in [compsci, phys, systems, agbuis, histor]] 

keyword = r'Computer science is the study of computation, automation, and information.[1] Computer science spans theoretical disciplines (such as algorithms, theory of computation, and information theory) to practical disciplines (including the design and implementation of hardware and software).[2][3] Computer science is generally considered an area of academic research and distinct from computer programming.[4] Algorithms and data structures are central to computer science.[5] The theory of computation concerns abstract models of computation and general classes of problems that can be solved using them. The fields of cryptography and computer security involve studying the means for secure communication and for preventing security vulnerabilities. Computer graphics and computational geometry address the generation of images. Programming language theory considers approaches to the description of computational processes, and database theory concerns the management of repositories of data. Human–computer interaction investigates the interfaces through which humans and computers interact, and software engineering focuses on the design and principles behind developing software. Areas such as operating systems, networks and embedded systems investigate the principles and design behind complex systems. Computer architecture describes the construction of computer components and computer-operated equipment. Artificial intelligence and machine learning aim to synthesize goal-orientated processes such as problem-solving, decision-making, environmental adaptation, planning and learning found in humans and animals. Within artificial intelligence, computer vision aims to understand and process image and video data, while natural-language processing aims to understand and process textual and linguistic data.'

cut_texts = [jieba.lcut(text) for text in texts]

dictionary = corpora.Dictionary(cut_texts)

feature_cnt = len(dictionary.token2id)

corpus = [dictionary.doc2bow(text) for text in cut_texts]

tfidf = models.TfidfModel(corpus)

kw_vector = dictionary.doc2bow(jieba.lcut(keyword))

index = similarities.SparseMatrixSimilarity(tfidf[corpus], num_features = feature_cnt)

sim = index[tfidf[kw_vector]]

for i in range(len(sim)):
    print('keyword is similar to text%d: %.5f' % (i + 1, sim[i]))
# Out:
# keyword is similar to text1: 0.95150
# keyword is similar to text2: 0.94754
# keyword is similar to text3: 0.91311
# keyword is similar to text4: 0.00000
# keyword is similar to text5: 0.00000

# %%
def run_gensim_similarities(text_dict: dict, keyword: str) -> dict:
    """
    texts: dict[pub_api_id: text] - bodies of texts to compare against the keyword
    keyword: str

    returns: dict[key: similarity_num]
    """

    keys, texts = text_dict.keys(), text_dict.values()
    cut_texts = [jieba.lcut(text) for text in texts]

    dictionary = corpora.Dictionary(cut_texts)
    feature_cnt = len(dictionary.token2id)
    corpus = [dictionary.doc2bow(text) for text in cut_texts]
    tfidf = models.TfidfModel(corpus)
    kw_vector = dictionary.doc2bow(jieba.lcut(keyword))
    index = similarities.SparseMatrixSimilarity(tfidf[corpus], num_features = feature_cnt)
    sim = index[tfidf[kw_vector]]
    return {key: val for key, val in zip(keys, sim)}

# %%
text_dict = {key: publications['abstract'][key] if publications['abstract'][key] else '' for key in [compsci, phys, systems, agbuis, histor]}

run_gensim_similarities(text_dict, keyword)
# Out:
# {'n230467SE': 0.95149904,
#  'n127269SE': 0.94753855,
#  'n165882SE': 0.91310966,
#  'n188661SE': 0.0,
#  'n51137SE': 0.0}
